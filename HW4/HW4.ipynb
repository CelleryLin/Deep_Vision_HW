# %% [markdown]
# # Neural Network for CIFAR10 Classification
# In this assignment, we will implement a two-layer fully-connected neural network for CIFAR10 classification.

# %% [markdown]
# ## Data Preparation and Visualization

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# import sys
# sys.path.append('/content/drive/MyDrive/HW4/')

# %%
# You may change `MODEL_DIR` to a existing local directory if you are not using Colab
MODEL_DIR = '/content/'
MODEL_PATH = MODEL_DIR + 'model.pt' if MODEL_DIR.endswith('/') else MODEL_DIR + '/model.pt'

# %%
from _utils import load_data, Dataset, Dataloader, FCL_Tests, ReLU_Tests, SCE_Tests, plot_curves, plot_result
import numpy as np
import matplotlib.pyplot as plt
import random
import torch

# %%
if torch.cuda.is_available():
  DEVICE = 'cuda'
  print(f'Using torch {torch.__version__}, device = {torch.cuda.get_device_name(0)}')
else:
  DEVICE = 'cpu'
  print(f'Using torch {torch.__version__}, device = cpu')
# Out:
# Using torch 1.13.1+cu116, device = Tesla T4

# %%
images, labels, classes = load_data()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar10/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./cifar10/cifar-10-python.tar.gz to ./cifar10/

# %%
print(f'Data type of images: {images.dtype} (value range: [{images.min()}, {images.max()}])')
print(f'Shape of images: {images.shape}')
print(f'Shape of labels: {labels.shape}')
print(f'Number of classes: {len(classes)}')
print(f'Classes: {classes}')
# Out:
# Data type of images: uint8 (value range: [0, 255])
# Shape of images: (50000, 32, 32, 3)
# Shape of labels: (50000,)
# Number of classes: 10
# Classes: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# Display samples of each class
plt.rcParams['figure.figsize'] = (16, 16)
num_classes = len(classes)
num_example = 10
for label, class_name in enumerate(classes):
  idxs = np.flatnonzero(labels == label)
  idxs = np.random.choice(idxs, num_example, replace=False)
  for i, idx in enumerate(idxs):
    plt_idx = i * num_classes + label + 1
    plt.subplot(num_example, num_classes, plt_idx)
    plt.imshow(images[idx]); plt.axis('off')
    if i == 0:
      plt.title(class_name)
plt.show()

# %%
# Data splitting with numpy array slicing
num_data = images.shape[0]
split_ratio = {'train': 0.6, 'valid': 0.2, 'test': 0.2}
num_valid_data = round(num_data * split_ratio['valid'])
num_test_data = round(num_data * split_ratio['test'])
num_train_data = num_data - (num_valid_data + num_test_data)

start_idx = 0
train_dataset = Dataset(images[start_idx:start_idx+num_train_data], labels[start_idx:start_idx+num_train_data])
start_idx += num_train_data

valid_dataset = Dataset(images[start_idx:start_idx+num_valid_data], labels[start_idx:start_idx+num_valid_data])
start_idx += num_valid_data

test_dataset = Dataset(images[start_idx:start_idx+num_test_data], labels[start_idx:start_idx+num_test_data])

print(f'Number of training data: {len(train_dataset)}')
print(f'Number of validation data: {len(valid_dataset)}')
print(f'Number of test data: {len(test_dataset)}')
# Out:
# Number of training data: 30000
# Number of validation data: 10000
# Number of test data: 10000

# %% [markdown]
# ## Layer Definition
# The architecture of our two-layer fully-connected neural network is like:
#
# Input $\rightarrow$ Fully-Connected Layer1 $\rightarrow$ ReLU  $\rightarrow$ Fully-Connected Layer2 $\rightarrow$ Softmax
#
# The learnable parameters are weights and bias of the two fully-connected layers. Let's name and clarify the parameters and their shapes:
#
# 1. Input data: $\mathbf{x}$, shape: ${N\times D}$
# 2. Weights of first fully-connected layer: $\mathbf{w_1}$, shape: ${D\times H}$
# 3. Bias of first fully-connected layer: $\mathbf{b_1}$, shape: ${H}$
# 4. Weights of second fully-connected layer: $\mathbf{w_2}$, shape: ${H\times C}$
# 5. Bias of second fully-connected layer: $\mathbf{b_2}$, shape: ${C}$
# 6. Output of the network: $\mathbf{S}$, shape: ${N\times C}$
#
# And then we can simply express the function of our network by:
# $$\mathbf{S} = \mathbf{w_2} * ReLU(\mathbf{w_1} * \mathbf{x} + \mathbf{b_1}) + \mathbf{b_2}$$
#
# Since the two fully-connected layers do the same job, that is, multiply weights with input and then plus bias, we define a class called FullyConnectedLayer to implement a single fully-connected layer.

# %%
class FullyConnectedLayer(object):
  def __init__(self, device='cpu'):
    self.dv = device
  def forward(self, x, w, b):
    N, D = x.shape
    Dw, F = w.shape
    assert Dw == D, f'Wrong shape of weights, expected ({D},{F}) but got ({Dw},{F})'
    Fb = b.shape[0]
    assert Fb == F, f'Wrong shape of bias, expected ({F},) but got ({Fb},)'
    out = torch.zeros((N, F)).to(self.dv)
    ####################
    # TODO:
    # 1. Implement fully connected layer with `w` * `x` + `b` and store the result in variable `out`
    ####################
    # -----START OF YOUR CODE-----

    out = torch.mm(x, w) + b
    
    # ------END OF YOUR CODE------
    self.cache = (x, w, b, out)
    return out
  def backward(self, backprop):
    N, F = backprop.shape
    dw = None
    db = None
    ####################
    # TODO:
    # 1. Derive the gradient of bias, i.e., d(out)/d(b)
    # 2. Multiply d(out)/d(b) with `backprop` due to chain rule, and then store the AVERAGED result in variable `db`
    # 3. Then, derive the gradient of weights, i.e., d(out)/d(w)
    # 4. Multiply d(out)/d(w) with `backprop` due to chain rule, and then store the AVERAGED result in variable `dw`
    # HINT: Shapes of `db` and `dw` should be (F,) and (D, F) respectively
    ####################
    # -----START OF YOUR CODE-----
    
    x, w, b, out = self.cache
    dw = torch.mm(x.T, backprop) / N
    db = torch.mean(backprop, dim=0)

    # ------END OF YOUR CODE------
    return dw, db

# %%
layer = FullyConnectedLayer()
FCL_Tests(layer)
# Out:
# Results of fully connected layer forward and backward tests: All passed.

# %% [markdown]
# ReLU (Rectified Linear Unit) is the currently most used non-linearity (or called activation function) in neural networks. Its formula as following:
# $$ReLU(t) = max(0, t)$$
#
# Since ReLU only allows positive values to be passed forward, any negative values of the input will not be able to propagate gradients during backpropagation.

# %%
class ReLU(object):
  def __init__(self):
    pass
  def forward(self, t):
    out = t.clone()
    ####################
    # TODO:
    # 1. Implement ReLU on `t` and store in variable `out`
    ####################
    # -----START OF YOUR CODE-----

    out = torch.max(t, torch.zeros_like(t))

    # ------END OF YOUR CODE------
    self.cache = (t, out)
    return out
  def backward(self, backprop):
    dt = torch.zeros_like(backprop)
    ####################
    # TODO:
    # 1. Derive d(out)/d(t)
    # 2. Multiply d(out)/d(t) with `backprop` due to chain rule, and then store the result in variable `dt`
    ####################
    # -----START OF YOUR CODE-----

    t, out = self.cache
    dt = (t > 0).float() * backprop
    
    # ------END OF YOUR CODE------
    return dt

# %%
layer = ReLU()
ReLU_Tests(layer)
# Out:
# Results of ReLU function tests: All passed.

# %% [markdown]
# Softmax is used to convert a vector of real numbers into a probability distribution over classes. It can be expressed mathematically as:
# $$softmax(\mathbf{S}_i)=\mathbf{p}_i=\frac{exp(\mathbf{S}_i)}{\sum_{j=1}^\mathbf{C}exp(\mathbf{S}_j)}$$
# And the cross-entropy loss, on the other hand, is a measure of the difference between the predicted probability distribution and the true probability distribution of the labels. Let $\mathbf{y}$ be **one-hot encoded** ground-truth label, that is, its shape would be the same with output of the network. Cross-entropy loss formula is defined as:
# $$CE = -\sum\mathbf{y}_i * log(\mathbf{p}_i)$$

# %%
class Softmax_CrossEntropy(object):
  def __init__(self):
    pass
  def forward(self, y, net_out):
    N, F = net_out.shape
    prob = torch.zeros_like(net_out)
    ####################
    # TODO:
    # 1. Implement Softmax and store the result in variable `prob`
    # HINT: Shape of `prob` should be (N, F)
    ####################
    # -----START OF YOUR CODE-----

    prob = torch.exp(net_out) / torch.sum(torch.exp(net_out), dim=1, keepdim=True)
    # ------END OF YOUR CODE------
    self.cache = (y, prob)
    pred_y = prob.argmax(dim=1)
    
    y_one_hot = torch.zeros_like(net_out)
    y_one_hot[np.arange(N), y] = 1
    loss = torch.zeros(1)
    ####################
    # TODO:
    # 1. Implement cross-entropy loss and store the result in variable `loss`
    ####################
    # -----START OF YOUR CODE-----

    loss = -torch.sum(y_one_hot * torch.log(prob)) / N
    
    # ------END OF YOUR CODE------
    return pred_y, loss
  def backward(self):
    y, prob = self.cache
    N, F = prob.shape
    ####################
    # TODO:
    # 1. Derive the gradient of `net_out` and store the result in variable `grad`
    ####################
    # -----START OF YOUR CODE-----

    y_one_hot = torch.zeros_like(prob)
    y_one_hot[np.arange(N), y] = 1

    grad = (prob - y_one_hot) / N
    
    # ------END OF YOUR CODE------
    return grad

# %%
layer = Softmax_CrossEntropy()
SCE_Tests(layer)
# Out:
# Results of softmax and cross entropy forward and backward tests: All passed.

# %% [markdown]
# ## Network Definition

# %%
class Classifier(object):
  def __init__(self, dim_in, dim_hidden, dim_out, device='cpu'):
    self.dv = device
    np.random.seed(0)
    self.params = {'w1': torch.from_numpy(np.random.randn(dim_in, dim_hidden)*0.8).to(self.dv),
             'b1': torch.zeros(dim_hidden).to(self.dv),
             'w2': torch.from_numpy(np.random.randn(dim_hidden, dim_out)*0.8).to(self.dv),
             'b2': torch.zeros(dim_out).to(self.dv)}
    layer1 = FullyConnectedLayer()
    activation = ReLU()
    layer2 = FullyConnectedLayer()
    self.net = [layer1, activation, layer2]
    self.loss_func = Softmax_CrossEntropy()
  def save_model(self, path):
    torch.save(self.params, path)
  def load_model(self, path):
    checkpoint = torch.load(path, map_location=self.dv)
    self.params = checkpoint
  def training(self, train_dataloader, valid_dataloader, epochs=200, learning_rate=1e-3, learning_rate_decay=0.95, verbose=1):
    print(f'Training with batch_size={train_dataloader[0][0].shape[0]}, hidden_dim={self.params["w1"].shape[1]}, learning_rate={learning_rate}, learning_rate_decay={learning_rate_decay}')
    train_loss_log = []
    train_acc_log = []
    valid_loss_log = []
    valid_acc_log = []
    best_val_loss = None
    for epoch in range(epochs):
      if verbose > 0 and (epoch+1) % verbose == 0:
        print(f'Epoch {epoch+1}:')
      single_epoch_log = ''
      train_loss = 0.0
      train_corr = 0.0; train_eval = 0.0
      for batch_idx in range(len(train_dataloader)):
        ### Model Input and Loss Calculation ###
        batch_data = train_dataloader[batch_idx]
        batch_img, batch_label = batch_data
        layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
        layer1_out = self.net[1].forward(layer1_out)
        layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
        pred_y, loss = self.loss_func.forward(batch_label, layer2_out)
        train_loss += loss.cpu().numpy()
        train_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
        train_eval += batch_img.shape[0]
        ### Backpropagation and Optimization ###
        params_grad = {}
        dloss_dout2 = self.loss_func.backward()
        dout2_dw2, dout2_db2 = self.net[2].backward(dloss_dout2)
        params_grad['w2'] = dout2_dw2; params_grad['b2'] = dout2_db2
        dout2_dout1 = self.net[1].backward(dloss_dout2.mm(self.params['w2'].T))
        dout1_dw1, dout1_db1 = self.net[0].backward(dout2_dout1)
        params_grad['w1'] = dout1_dw1; params_grad['b1'] = dout1_db1
        ####################
        # TODO:
        # 1. Update model parameters, i.e., `self.params`, by gradient descent
        ####################
        # -----START OF YOUR CODE-----

        self.params['w1'] -= learning_rate * params_grad['w1']
        self.params['b1'] -= learning_rate * params_grad['b1']
        self.params['w2'] -= learning_rate * params_grad['w2']
        self.params['b2'] -= learning_rate * params_grad['b2']
        
        # ------END OF YOUR CODE------
      train_loss_log.append(train_loss/train_eval)
      train_acc_log.append(100*train_corr/train_eval)
      single_epoch_log += f'Training accuracy: {format(train_acc_log[-1], ".2f")}%, loss: {format(train_loss_log[-1], ".4f")}\n'
      train_dataloader.shuffle()

      valid_loss = 0.0
      valid_corr = 0.0; valid_eval = 0.0
      for batch_idx in range(len(valid_dataloader)):
        ### Model Input and Loss Calculation ###
        batch_data = valid_dataloader[batch_idx]
        batch_img, batch_label = batch_data
        layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
        layer1_out = self.net[1].forward(layer1_out)
        layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
        pred_y, loss = self.loss_func.forward(batch_label, layer2_out)
        valid_loss += loss.cpu().numpy()
        valid_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
        valid_eval += batch_img.shape[0]
      valid_loss_log.append(valid_loss/valid_eval)
      valid_acc_log.append(100*valid_corr/valid_eval)
      single_epoch_log += f'Validaion accuracy: {format(valid_acc_log[-1], ".2f")}%, loss: {format(valid_loss_log[-1], ".4f")}'
      if best_val_loss is None or valid_loss < best_val_loss:
        best_val_loss = valid_loss
        self.save_model(MODEL_PATH)
        if verbose == 1:
          single_epoch_log = '[MODEL SAVED]\n' + single_epoch_log
      if verbose > 0 and (epoch+1) % verbose == 0:
        print(single_epoch_log)
      learning_rate *= learning_rate_decay # update learning_rate every epoch
    return train_loss_log,train_acc_log,valid_loss_log,valid_acc_log
  def test(self, test_dataloader):
    total_corr = 0; total_eval = 0
    for batch_idx in range(len(test_dataloader)):
      ### Model Input ###
      batch_data = test_dataloader[batch_idx]
      batch_img, batch_label = batch_data
      layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
      layer1_out = self.net[1].forward(layer1_out)
      layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
      pred_y, _ = self.loss_func.forward(batch_label, layer2_out)
      total_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
      total_eval += batch_img.shape[0]
    print(f'Got {total_corr} correct prediction in {total_eval} test data, accuracy: {format((total_corr*1.0/total_eval)*100, ".2f")}%')

# %% [markdown]
# ## Searching for Best Hyperparameters
# Hyperparameters are configuration variables that set by users before model training. They influence the learning process and the final performance of the model. The goal of selecting optimal hyperparameters is to improve the model's accuracy and generalization ability.
#
# Hyperparameters in this assignment include hidden layer size, batch size, learning rate, and learning rate decay. You may change candidate values of them in the following cells and observe which might be useful to optimize the model. Howerver,  as running the whole section may take a while, you are allowed to not running all of the cells.

# %%
# Configurations
IN_DIM = np.prod(images[0].shape)
OUT_DIM = len(classes)

# %%
# Hyperparameters
BATCH_SIZE = 16
LR = 1e-3
LR_DECAY = 0.95
HIDEEN_DIM = 64

# %%
lr_cand = [1e-2, 1e-3, 1e-4]
train_acc = []
valid_acc = []

for lr in lr_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
  valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
  model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=80, learning_rate=lr, learning_rate_decay=LR_DECAY, verbose=1)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(lr_cand, train_acc, valid_acc)
# Out:
# Training with batch_size=16, hidden_dim=64, learning_rate=0.01, learning_rate_decay=0.95
# Epoch 1:
# [MODEL SAVED]
# Training accuracy: 19.96%, loss: 1.9786
# Validaion accuracy: 15.94%, loss: 1.6876
# Epoch 2:
# [MODEL SAVED]
# Training accuracy: 23.89%, loss: 0.9416
# Validaion accuracy: 16.13%, loss: 1.2178
# Epoch 3:
# [MODEL SAVED]
# Training accuracy: 24.62%, loss: 0.5677
# Validaion accuracy: 16.66%, loss: 0.6765
# Epoch 4:
# [MODEL SAVED]
# Training accuracy: 26.08%, loss: 0.3677
# Validaion accuracy: 15.63%, loss: 0.4295
# Epoch 5:
# [MODEL SAVED]
# Training accuracy: 27.50%, loss: 0.2524
# Validaion accuracy: 17.56%, loss: 0.2777
# Epoch 6:
# [MODEL SAVED]
# Training accuracy: 29.61%, loss: 0.1790
# Validaion accuracy: 18.77%, loss: 0.2364
# Epoch 7:
# [MODEL SAVED]
# Training accuracy: 34.09%, loss: 0.1583
# Validaion accuracy: 17.04%, loss: 0.2202
# Epoch 8:
# [MODEL SAVED]
# Training accuracy: 36.48%, loss: 0.1334
# Validaion accuracy: 19.36%, loss: 0.1755
# Epoch 9:
# Training accuracy: 34.20%, loss: 0.1394
# Validaion accuracy: 15.59%, loss: 0.1847
# Epoch 10:
# [MODEL SAVED]
# Training accuracy: 33.56%, loss: 0.1356
# Validaion accuracy: 17.94%, loss: 0.1715
# Epoch 11:
# Training accuracy: 35.10%, loss: 0.1300
# Validaion accuracy: 19.53%, loss: 0.1757
# Epoch 12:
# [MODEL SAVED]
# Training accuracy: 35.72%, loss: 0.1272
# Validaion accuracy: 20.65%, loss: 0.1619
# Epoch 13:
# Training accuracy: 36.16%, loss: 0.1257
# Validaion accuracy: 16.77%, loss: 0.1873
# Epoch 14:
# Training accuracy: 34.97%, loss: 0.1246
# Validaion accuracy: 19.93%, loss: 0.1775
# Epoch 15:
# Training accuracy: 35.83%, loss: 0.1288
# Validaion accuracy: 16.27%, loss: 0.1701
# Epoch 16:
# Training accuracy: 35.63%, loss: 0.1230
# Validaion accuracy: 17.36%, loss: 0.1684
# Epoch 17:
# Training accuracy: 34.27%, loss: 0.1287
# Validaion accuracy: 19.22%, loss: 0.1738
# Epoch 18:
# [MODEL SAVED]
# Training accuracy: 34.82%, loss: 0.1276
# Validaion accuracy: 18.23%, loss: 0.1588
# Epoch 19:
# Training accuracy: 33.54%, loss: 0.1296
# Validaion accuracy: 18.18%, loss: 0.1593
# Epoch 20:
# Training accuracy: 34.21%, loss: 0.1275
# Validaion accuracy: 18.91%, loss: 0.1613
# Epoch 21:
# [MODEL SAVED]
# Training accuracy: 34.57%, loss: 0.1226
# Validaion accuracy: 21.55%, loss: 0.1586
# Epoch 22:
# [MODEL SAVED]
# Training accuracy: 36.43%, loss: 0.1278
# Validaion accuracy: 21.41%, loss: 0.1461
# Epoch 23:
# [MODEL SAVED]
# Training accuracy: 34.57%, loss: 0.1242
# Validaion accuracy: 23.04%, loss: 0.1454
# Epoch 24:
# Training accuracy: 34.37%, loss: 0.1254
# Validaion accuracy: 21.16%, loss: 0.1545
# Epoch 25:
# Training accuracy: 33.61%, loss: 0.1223
# Validaion accuracy: 21.56%, loss: 0.1588
# Epoch 26:
# Training accuracy: 34.12%, loss: 0.1282
# Validaion accuracy: 19.33%, loss: 0.1528
# Epoch 27:
# [MODEL SAVED]
# Training accuracy: 33.44%, loss: 0.1247
# Validaion accuracy: 23.67%, loss: 0.1446
# Epoch 28:
# Training accuracy: 31.77%, loss: 0.1280
# Validaion accuracy: 21.95%, loss: 0.1480
# Epoch 29:
# [MODEL SAVED]
# Training accuracy: 32.74%, loss: 0.1266
# Validaion accuracy: 22.45%, loss: 0.1418
# Epoch 30:
# Training accuracy: 31.96%, loss: 0.1284
# Validaion accuracy: 19.99%, loss: 0.1478
# Epoch 31:
# Training accuracy: 34.04%, loss: 0.1250
# Validaion accuracy: 23.13%, loss: 0.1479
# Epoch 32:
# [MODEL SAVED]
# Training accuracy: 31.84%, loss: 0.1291
# Validaion accuracy: 24.96%, loss: 0.1386
# Epoch 33:
# Training accuracy: 31.91%, loss: 0.1279
# Validaion accuracy: 22.22%, loss: 0.1446
# Epoch 34:
# Training accuracy: 31.91%, loss: 0.1251
# Validaion accuracy: 22.47%, loss: 0.1432
# Epoch 35:
# Training accuracy: 31.90%, loss: 0.1303
# Validaion accuracy: 23.32%, loss: 0.1417
# Epoch 36:
# Training accuracy: 30.71%, loss: 0.1295
# Validaion accuracy: 18.35%, loss: 0.1459
# Epoch 37:
# Training accuracy: 32.17%, loss: 0.1278
# Validaion accuracy: 23.08%, loss: 0.1435
# Epoch 38:
# Training accuracy: 31.80%, loss: 0.1268
# Validaion accuracy: 21.01%, loss: 0.1483
# Epoch 39:
# Training accuracy: 33.09%, loss: 0.1249
# Validaion accuracy: 22.99%, loss: 0.1434
# Epoch 40:
# Training accuracy: 31.17%, loss: 0.1261
# Validaion accuracy: 22.83%, loss: 0.1388
# Epoch 41:
# Training accuracy: 33.10%, loss: 0.1257
# Validaion accuracy: 23.20%, loss: 0.1411
# Epoch 42:
# [MODEL SAVED]
# Training accuracy: 28.73%, loss: 0.1313
# Validaion accuracy: 22.12%, loss: 0.1384
# Epoch 43:
# Training accuracy: 30.82%, loss: 0.1257
# Validaion accuracy: 26.20%, loss: 0.1387
# Epoch 44:
# Training accuracy: 30.49%, loss: 0.1309
# Validaion accuracy: 22.11%, loss: 0.1385
# Epoch 45:
# [MODEL SAVED]
# Training accuracy: 30.74%, loss: 0.1268
# Validaion accuracy: 21.35%, loss: 0.1367
# Epoch 46:
# Training accuracy: 30.92%, loss: 0.1305
# Validaion accuracy: 21.47%, loss: 0.1372
# Epoch 47:
# [MODEL SAVED]
# Training accuracy: 29.41%, loss: 0.1306
# Validaion accuracy: 23.24%, loss: 0.1360
# Epoch 48:
# [MODEL SAVED]
# Training accuracy: 29.94%, loss: 0.1275
# Validaion accuracy: 25.79%, loss: 0.1359
# Epoch 49:
# [MODEL SAVED]
# Training accuracy: 29.74%, loss: 0.1279
# Validaion accuracy: 26.36%, loss: 0.1358
# Epoch 50:
# Training accuracy: 28.90%, loss: 0.1283
# Validaion accuracy: 23.02%, loss: 0.1387
# Epoch 51:
# Training accuracy: 28.81%, loss: 0.1285
# Validaion accuracy: 24.61%, loss: 0.1378
# Epoch 52:
# [MODEL SAVED]
# Training accuracy: 29.95%, loss: 0.1303
# Validaion accuracy: 24.66%, loss: 0.1348
# Epoch 53:
# Training accuracy: 29.92%, loss: 0.1319
# Validaion accuracy: 25.34%, loss: 0.1382
# Epoch 54:
# Training accuracy: 28.17%, loss: 0.1299
# Validaion accuracy: 22.97%, loss: 0.1379
# Epoch 55:
# Training accuracy: 28.85%, loss: 0.1293
# Validaion accuracy: 25.60%, loss: 0.1354
# Epoch 56:
# Training accuracy: 29.55%, loss: 0.1308
# Validaion accuracy: 25.26%, loss: 0.1407
# Epoch 57:
# Training accuracy: 30.62%, loss: 0.1283
# Validaion accuracy: 19.18%, loss: 0.1406
# Epoch 58:
# Training accuracy: 30.14%, loss: 0.1270
# Validaion accuracy: 22.37%, loss: 0.1371
# Epoch 59:
# Training accuracy: 30.17%, loss: 0.1300
# Validaion accuracy: 24.86%, loss: 0.1351
# Epoch 60:
# [MODEL SAVED]
# Training accuracy: 30.23%, loss: 0.1298
# Validaion accuracy: 25.32%, loss: 0.1346
# Epoch 61:
# Training accuracy: 29.05%, loss: 0.1307
# Validaion accuracy: 20.84%, loss: 0.1368
# Epoch 62:
# Training accuracy: 29.11%, loss: 0.1312
# Validaion accuracy: 22.64%, loss: 0.1386
# Epoch 63:
# Training accuracy: 27.63%, loss: 0.1310
# Validaion accuracy: 22.14%, loss: 0.1364
# Epoch 64:
# Training accuracy: 30.18%, loss: 0.1293
# Validaion accuracy: 24.31%, loss: 0.1358
# Epoch 65:
# Training accuracy: 27.70%, loss: 0.1316
# Validaion accuracy: 20.35%, loss: 0.1356
# Epoch 66:
# Training accuracy: 27.58%, loss: 0.1304
# Validaion accuracy: 25.89%, loss: 0.1352
# Epoch 67:
# [MODEL SAVED]
# Training accuracy: 28.57%, loss: 0.1319
# Validaion accuracy: 25.18%, loss: 0.1338
# Epoch 68:
# Training accuracy: 27.41%, loss: 0.1304
# Validaion accuracy: 21.93%, loss: 0.1355
# Epoch 69:
# Training accuracy: 27.73%, loss: 0.1304
# Validaion accuracy: 26.05%, loss: 0.1345
# Epoch 70:
# Training accuracy: 29.66%, loss: 0.1280
# Validaion accuracy: 23.05%, loss: 0.1343
# Epoch 71:
# [MODEL SAVED]
# Training accuracy: 27.29%, loss: 0.1304
# Validaion accuracy: 26.05%, loss: 0.1331
# Epoch 72:
# Training accuracy: 27.43%, loss: 0.1319
# Validaion accuracy: 23.58%, loss: 0.1354
# Epoch 73:
# [MODEL SAVED]
# Training accuracy: 29.36%, loss: 0.1287
# Validaion accuracy: 28.69%, loss: 0.1323
# Epoch 74:
# [MODEL SAVED]
# Training accuracy: 27.96%, loss: 0.1312
# Validaion accuracy: 27.05%, loss: 0.1320
# Epoch 75:
# Training accuracy: 27.42%, loss: 0.1333
# Validaion accuracy: 26.12%, loss: 0.1329
# Epoch 76:
# Training accuracy: 29.85%, loss: 0.1283
# Validaion accuracy: 25.94%, loss: 0.1320
# Epoch 77:
# Training accuracy: 28.17%, loss: 0.1309
# Validaion accuracy: 25.67%, loss: 0.1337
# Epoch 78:
# [MODEL SAVED]
# Training accuracy: 26.96%, loss: 0.1292
# Validaion accuracy: 26.53%, loss: 0.1318
# Epoch 79:
# Training accuracy: 28.61%, loss: 0.1326
# Validaion accuracy: 25.53%, loss: 0.1320
# Epoch 80:
# Training accuracy: 27.80%, loss: 0.1334
# Validaion accuracy: 25.48%, loss: 0.1337
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Epoch 1:
# [MODEL SAVED]
# Training accuracy: 10.91%, loss: nan
# Validaion accuracy: 11.15%, loss: 3.5118
# Epoch 2:
# [MODEL SAVED]
# Training accuracy: 12.37%, loss: 2.9665
# Validaion accuracy: 11.87%, loss: 2.8994
# Epoch 3:
# [MODEL SAVED]
# Training accuracy: 15.23%, loss: 2.5204
# Validaion accuracy: 14.57%, loss: 2.5092
# Epoch 4:
# [MODEL SAVED]
# Training accuracy: 15.10%, loss: 2.1824
# Validaion accuracy: 14.69%, loss: 2.2869
# Epoch 5:
# [MODEL SAVED]
# Training accuracy: 14.55%, loss: 2.0794
# Validaion accuracy: 17.57%, loss: 2.1231
# Epoch 6:
# [MODEL SAVED]
# Training accuracy: 15.72%, loss: 1.8861
# Validaion accuracy: 15.71%, loss: 2.0268
# Epoch 7:
# [MODEL SAVED]
# Training accuracy: 17.04%, loss: 1.7535
# Validaion accuracy: 15.44%, loss: 1.8990
# Epoch 8:
# [MODEL SAVED]
# Training accuracy: 17.02%, loss: 1.6831
# Validaion accuracy: 16.65%, loss: 1.7997
# Epoch 9:
# [MODEL SAVED]
# Training accuracy: 17.37%, loss: 1.5705
# Validaion accuracy: 15.21%, loss: 1.7382
# Epoch 10:
# [MODEL SAVED]
# Training accuracy: 16.21%, loss: 1.5196
# Validaion accuracy: 15.32%, loss: 1.6505
# Epoch 11:
# [MODEL SAVED]
# Training accuracy: 17.35%, loss: 1.4678
# Validaion accuracy: 15.85%, loss: 1.5778
# Epoch 12:
# [MODEL SAVED]
# Training accuracy: 16.22%, loss: 1.3845
# Validaion accuracy: 15.37%, loss: 1.5391
# Epoch 13:
# [MODEL SAVED]
# Training accuracy: 17.92%, loss: 1.3139
# Validaion accuracy: 16.33%, loss: 1.4853
# Epoch 14:
# [MODEL SAVED]
# Training accuracy: 17.01%, loss: 1.2936
# Validaion accuracy: 15.69%, loss: 1.4536
# Epoch 15:
# [MODEL SAVED]
# Training accuracy: 16.86%, loss: 1.3054
# Validaion accuracy: 16.57%, loss: 1.3913
# Epoch 16:
# [MODEL SAVED]
# Training accuracy: 17.75%, loss: 1.1892
# Validaion accuracy: 16.49%, loss: 1.3402
# Epoch 17:
# [MODEL SAVED]
# Training accuracy: 15.81%, loss: 1.2687
# Validaion accuracy: 16.41%, loss: 1.3057
# Epoch 18:
# [MODEL SAVED]
# Training accuracy: 18.71%, loss: 1.1783
# Validaion accuracy: 17.04%, loss: 1.2708
# Epoch 19:
# [MODEL SAVED]
# Training accuracy: 16.62%, loss: 1.1538
# Validaion accuracy: 18.25%, loss: 1.2416
# Epoch 20:
# [MODEL SAVED]
# Training accuracy: 18.00%, loss: 1.1066
# Validaion accuracy: 18.41%, loss: 1.2063
# Epoch 21:
# [MODEL SAVED]
# Training accuracy: 17.18%, loss: 1.0969
# Validaion accuracy: 17.29%, loss: 1.1804
# Epoch 22:
# [MODEL SAVED]
# Training accuracy: 16.76%, loss: 1.0878
# Validaion accuracy: 17.77%, loss: 1.1421
# Epoch 23:
# [MODEL SAVED]
# Training accuracy: 17.12%, loss: 1.0641
# Validaion accuracy: 18.25%, loss: 1.1227
# Epoch 24:
# [MODEL SAVED]
# Training accuracy: 18.33%, loss: 1.0220
# Validaion accuracy: 17.45%, loss: 1.1034
# Epoch 25:
# [MODEL SAVED]
# Training accuracy: 17.21%, loss: 1.0083
# Validaion accuracy: 17.20%, loss: 1.0920
# Epoch 26:
# [MODEL SAVED]
# Training accuracy: 18.40%, loss: 0.9769
# Validaion accuracy: 17.04%, loss: 1.0749
# Epoch 27:
# [MODEL SAVED]
# Training accuracy: 17.20%, loss: 0.9608
# Validaion accuracy: 16.81%, loss: 1.0548
# Epoch 28:
# [MODEL SAVED]
# Training accuracy: 18.58%, loss: 0.9610
# Validaion accuracy: 17.57%, loss: 1.0390
# Epoch 29:
# [MODEL SAVED]
# Training accuracy: 16.81%, loss: 0.9574
# Validaion accuracy: 17.29%, loss: 1.0259
# Epoch 30:
# [MODEL SAVED]
# Training accuracy: 17.65%, loss: 0.9296
# Validaion accuracy: 16.56%, loss: 1.0192
# Epoch 31:
# [MODEL SAVED]
# Training accuracy: 18.64%, loss: 0.9315
# Validaion accuracy: 16.97%, loss: 1.0003
# Epoch 32:
# [MODEL SAVED]
# Training accuracy: 18.98%, loss: 0.9078
# Validaion accuracy: 16.88%, loss: 0.9874
# Epoch 33:
# [MODEL SAVED]
# Training accuracy: 18.00%, loss: 0.8909
# Validaion accuracy: 17.78%, loss: 0.9758
# Epoch 34:
# [MODEL SAVED]
# Training accuracy: 19.04%, loss: 0.8653
# Validaion accuracy: 17.04%, loss: 0.9599
# Epoch 35:
# [MODEL SAVED]
# Training accuracy: 17.29%, loss: 0.8956
# Validaion accuracy: 17.29%, loss: 0.9591
# Epoch 36:
# [MODEL SAVED]
# Training accuracy: 17.58%, loss: 0.8946
# Validaion accuracy: 17.50%, loss: 0.9426
# Epoch 37:
# [MODEL SAVED]
# Training accuracy: 18.99%, loss: 0.8670
# Validaion accuracy: 18.09%, loss: 0.9369
# Epoch 38:
# [MODEL SAVED]
# Training accuracy: 17.83%, loss: 0.8451
# Validaion accuracy: 17.45%, loss: 0.9275
# Epoch 39:
# [MODEL SAVED]
# Training accuracy: 17.94%, loss: 0.8470
# Validaion accuracy: 17.18%, loss: 0.9201
# Epoch 40:
# [MODEL SAVED]
# Training accuracy: 19.00%, loss: 0.8343
# Validaion accuracy: 17.61%, loss: 0.9087
# Epoch 41:
# Training accuracy: 18.34%, loss: 0.8219
# Validaion accuracy: 17.67%, loss: 0.9108
# Epoch 42:
# [MODEL SAVED]
# Training accuracy: 16.26%, loss: 0.8599
# Validaion accuracy: 16.88%, loss: 0.9023
# Epoch 43:
# [MODEL SAVED]
# Training accuracy: 18.37%, loss: 0.8290
# Validaion accuracy: 17.05%, loss: 0.8938
# Epoch 44:
# [MODEL SAVED]
# Training accuracy: 18.30%, loss: 0.8329
# Validaion accuracy: 17.68%, loss: 0.8926
# Epoch 45:
# [MODEL SAVED]
# Training accuracy: 19.73%, loss: 0.8002
# Validaion accuracy: 17.77%, loss: 0.8789
# Epoch 46:
# [MODEL SAVED]
# Training accuracy: 17.95%, loss: 0.8162
# Validaion accuracy: 17.78%, loss: 0.8771
# Epoch 47:
# [MODEL SAVED]
# Training accuracy: 16.92%, loss: 0.8228
# Validaion accuracy: 17.61%, loss: 0.8711
# Epoch 48:
# [MODEL SAVED]
# Training accuracy: 17.26%, loss: 0.7922
# Validaion accuracy: 17.20%, loss: 0.8694
# Epoch 49:
# Training accuracy: 18.41%, loss: 0.7968
# Validaion accuracy: 17.58%, loss: 0.8704
# Epoch 50:
# [MODEL SAVED]
# Training accuracy: 17.64%, loss: 0.8059
# Validaion accuracy: 17.45%, loss: 0.8599
# Epoch 51:
# [MODEL SAVED]
# Training accuracy: 17.89%, loss: 0.7893
# Validaion accuracy: 17.78%, loss: 0.8580
# Epoch 52:
# [MODEL SAVED]
# Training accuracy: 18.27%, loss: 0.8017
# Validaion accuracy: 18.39%, loss: 0.8520
# Epoch 53:
# [MODEL SAVED]
# Training accuracy: 18.32%, loss: 0.7948
# Validaion accuracy: 17.32%, loss: 0.8507
# Epoch 54:
# [MODEL SAVED]
# Training accuracy: 18.12%, loss: 0.7783
# Validaion accuracy: 17.61%, loss: 0.8472
# Epoch 55:
# [MODEL SAVED]
# Training accuracy: 17.62%, loss: 0.7871
# Validaion accuracy: 17.61%, loss: 0.8472
# Epoch 56:
# [MODEL SAVED]
# Training accuracy: 18.20%, loss: 0.7697
# Validaion accuracy: 17.77%, loss: 0.8431
# Epoch 57:
# [MODEL SAVED]
# Training accuracy: 17.53%, loss: 0.7565
# Validaion accuracy: 17.84%, loss: 0.8408
# Epoch 58:
# Training accuracy: 19.07%, loss: 0.7487
# Validaion accuracy: 16.75%, loss: 0.8408
# Epoch 59:
# [MODEL SAVED]
# Training accuracy: 16.93%, loss: 0.7835
# Validaion accuracy: 17.34%, loss: 0.8351
# Epoch 60:
# [MODEL SAVED]
# Training accuracy: 18.24%, loss: 0.7770
# Validaion accuracy: 17.80%, loss: 0.8319
# Epoch 61:
# [MODEL SAVED]
# Training accuracy: 16.28%, loss: 0.7835
# Validaion accuracy: 17.43%, loss: 0.8298
# Epoch 62:
# Training accuracy: 16.77%, loss: 0.7911
# Validaion accuracy: 17.71%, loss: 0.8298
# Epoch 63:
# [MODEL SAVED]
# Training accuracy: 19.63%, loss: 0.7507
# Validaion accuracy: 17.66%, loss: 0.8282
# Epoch 64:
# [MODEL SAVED]
# Training accuracy: 20.17%, loss: 0.7343
# Validaion accuracy: 18.07%, loss: 0.8261
# Epoch 65:
# [MODEL SAVED]
# Training accuracy: 18.16%, loss: 0.7785
# Validaion accuracy: 17.07%, loss: 0.8250
# Epoch 66:
# [MODEL SAVED]
# Training accuracy: 17.24%, loss: 0.7566
# Validaion accuracy: 17.55%, loss: 0.8240
# Epoch 67:
# [MODEL SAVED]
# Training accuracy: 17.98%, loss: 0.7655
# Validaion accuracy: 17.71%, loss: 0.8208
# Epoch 68:
# [MODEL SAVED]
# Training accuracy: 18.00%, loss: 0.7472
# Validaion accuracy: 17.55%, loss: 0.8204
# Epoch 69:
# Training accuracy: 17.33%, loss: 0.7469
# Validaion accuracy: 17.23%, loss: 0.8205
# Epoch 70:
# [MODEL SAVED]
# Training accuracy: 17.43%, loss: 0.7304
# Validaion accuracy: 17.39%, loss: 0.8180
# Epoch 71:
# [MODEL SAVED]
# Training accuracy: 17.41%, loss: 0.7288
# Validaion accuracy: 17.50%, loss: 0.8176
# Epoch 72:
# [MODEL SAVED]
# Training accuracy: 18.17%, loss: 0.7358
# Validaion accuracy: 17.39%, loss: 0.8157
# Epoch 73:
# [MODEL SAVED]
# Training accuracy: 18.61%, loss: 0.7306
# Validaion accuracy: 18.11%, loss: 0.8108
# Epoch 74:
# Training accuracy: 17.64%, loss: 0.7650
# Validaion accuracy: 17.87%, loss: 0.8112
# Epoch 75:
# [MODEL SAVED]
# Training accuracy: 18.54%, loss: 0.7561
# Validaion accuracy: 17.55%, loss: 0.8097
# Epoch 76:
# Training accuracy: 17.64%, loss: 0.7209
# Validaion accuracy: 18.14%, loss: 0.8098
# Epoch 77:
# Training accuracy: 17.44%, loss: 0.7339
# Validaion accuracy: 17.87%, loss: 0.8101
# Epoch 78:
# Training accuracy: 18.85%, loss: 0.7393
# Validaion accuracy: 17.55%, loss: 0.8099
# Epoch 79:
# [MODEL SAVED]
# Training accuracy: 18.81%, loss: 0.7397
# Validaion accuracy: 17.87%, loss: 0.8082
# Epoch 80:
# [MODEL SAVED]
# Training accuracy: 18.72%, loss: 0.7465
# Validaion accuracy: 17.55%, loss: 0.8070
# Training with batch_size=16, hidden_dim=64, learning_rate=0.0001, learning_rate_decay=0.95
# Epoch 1:
# [MODEL SAVED]
# Training accuracy: 9.67%, loss: nan
# Validaion accuracy: 9.10%, loss: 7.5118
# Epoch 2:
# [MODEL SAVED]
# Training accuracy: 10.53%, loss: 6.1591
# Validaion accuracy: 7.99%, loss: 5.9967
# Epoch 3:
# [MODEL SAVED]
# Training accuracy: 10.65%, loss: 5.4081
# Validaion accuracy: 9.11%, loss: 5.3330
# Epoch 4:
# [MODEL SAVED]
# Training accuracy: 9.42%, loss: 4.8768
# Validaion accuracy: 9.43%, loss: 4.7963
# Epoch 5:
# [MODEL SAVED]
# Training accuracy: 10.81%, loss: 4.4326
# Validaion accuracy: 9.43%, loss: 4.3484
# Epoch 6:
# [MODEL SAVED]
# Training accuracy: 11.55%, loss: 3.9484
# Validaion accuracy: 9.11%, loss: 4.0428
# Epoch 7:
# [MODEL SAVED]
# Training accuracy: 11.60%, loss: 3.6971
# Validaion accuracy: 9.27%, loss: 3.8771
# Epoch 8:
# [MODEL SAVED]
# Training accuracy: 9.87%, loss: 3.7848
# Validaion accuracy: 10.07%, loss: 3.7513
# Epoch 9:
# [MODEL SAVED]
# Training accuracy: 10.95%, loss: 3.4806
# Validaion accuracy: 9.91%, loss: 3.6911
# Epoch 10:
# [MODEL SAVED]
# Training accuracy: 11.23%, loss: 3.4706
# Validaion accuracy: 10.55%, loss: 3.6322
# Epoch 11:
# [MODEL SAVED]
# Training accuracy: 10.26%, loss: 3.5322
# Validaion accuracy: 11.03%, loss: 3.5617
# Epoch 12:
# [MODEL SAVED]
# Training accuracy: 10.17%, loss: 3.3500
# Validaion accuracy: 11.03%, loss: 3.5201
# Epoch 13:
# [MODEL SAVED]
# Training accuracy: 11.29%, loss: 3.2768
# Validaion accuracy: 10.55%, loss: 3.4802
# Epoch 14:
# [MODEL SAVED]
# Training accuracy: 11.55%, loss: 3.3230
# Validaion accuracy: 10.71%, loss: 3.4511
# Epoch 15:
# [MODEL SAVED]
# Training accuracy: 10.36%, loss: 3.4179
# Validaion accuracy: 10.55%, loss: 3.4095
# Epoch 16:
# [MODEL SAVED]
# Training accuracy: 11.14%, loss: 3.1650
# Validaion accuracy: 10.75%, loss: 3.3689
# Epoch 17:
# [MODEL SAVED]
# Training accuracy: 10.84%, loss: 3.3174
# Validaion accuracy: 11.23%, loss: 3.3417
# Epoch 18:
# [MODEL SAVED]
# Training accuracy: 11.37%, loss: 3.2356
# Validaion accuracy: 11.35%, loss: 3.3116
# Epoch 19:
# [MODEL SAVED]
# Training accuracy: 10.76%, loss: 3.1493
# Validaion accuracy: 11.39%, loss: 3.2821
# Epoch 20:
# [MODEL SAVED]
# Training accuracy: 11.44%, loss: 3.1874
# Validaion accuracy: 10.91%, loss: 3.2501
# Epoch 21:
# [MODEL SAVED]
# Training accuracy: 10.69%, loss: 3.1719
# Validaion accuracy: 11.31%, loss: 3.2244
# Epoch 22:
# [MODEL SAVED]
# Training accuracy: 11.18%, loss: 3.1600
# Validaion accuracy: 11.47%, loss: 3.1998
# Epoch 23:
# [MODEL SAVED]
# Training accuracy: 10.27%, loss: 3.1135
# Validaion accuracy: 11.31%, loss: 3.1817
# Epoch 24:
# [MODEL SAVED]
# Training accuracy: 10.86%, loss: 3.0272
# Validaion accuracy: 11.23%, loss: 3.1580
# Epoch 25:
# [MODEL SAVED]
# Training accuracy: 11.34%, loss: 2.9998
# Validaion accuracy: 11.15%, loss: 3.1397
# Epoch 26:
# [MODEL SAVED]
# Training accuracy: 10.75%, loss: 2.9811
# Validaion accuracy: 11.07%, loss: 3.1257
# Epoch 27:
# [MODEL SAVED]
# Training accuracy: 11.54%, loss: 3.0720
# Validaion accuracy: 10.91%, loss: 3.1112
# Epoch 28:
# [MODEL SAVED]
# Training accuracy: 11.16%, loss: 2.9837
# Validaion accuracy: 10.75%, loss: 3.0956
# Epoch 29:
# [MODEL SAVED]
# Training accuracy: 11.46%, loss: 2.9529
# Validaion accuracy: 10.75%, loss: 3.0782
# Epoch 30:
# [MODEL SAVED]
# Training accuracy: 11.99%, loss: 2.8795
# Validaion accuracy: 10.91%, loss: 3.0639
# Epoch 31:
# [MODEL SAVED]
# Training accuracy: 11.03%, loss: 2.9642
# Validaion accuracy: 10.75%, loss: 3.0519
# Epoch 32:
# [MODEL SAVED]
# Training accuracy: 11.77%, loss: 2.9175
# Validaion accuracy: 10.91%, loss: 3.0374
# Epoch 33:
# [MODEL SAVED]
# Training accuracy: 12.30%, loss: 2.8893
# Validaion accuracy: 11.39%, loss: 3.0215
# Epoch 34:
# [MODEL SAVED]
# Training accuracy: 12.74%, loss: 2.8407
# Validaion accuracy: 11.23%, loss: 3.0092
# Epoch 35:
# [MODEL SAVED]
# Training accuracy: 11.49%, loss: 2.8707
# Validaion accuracy: 11.71%, loss: 3.0002
# Epoch 36:
# [MODEL SAVED]
# Training accuracy: 11.85%, loss: 2.8200
# Validaion accuracy: 11.71%, loss: 2.9920
# Epoch 37:
# [MODEL SAVED]
# Training accuracy: 11.93%, loss: 2.8732
# Validaion accuracy: 11.71%, loss: 2.9856
# Epoch 38:
# [MODEL SAVED]
# Training accuracy: 11.41%, loss: 2.8384
# Validaion accuracy: 12.03%, loss: 2.9774
# Epoch 39:
# [MODEL SAVED]
# Training accuracy: 12.05%, loss: 2.7983
# Validaion accuracy: 12.19%, loss: 2.9700
# Epoch 40:
# [MODEL SAVED]
# Training accuracy: 12.55%, loss: 2.8250
# Validaion accuracy: 12.03%, loss: 2.9596
# Epoch 41:
# [MODEL SAVED]
# Training accuracy: 12.02%, loss: 2.8307
# Validaion accuracy: 12.35%, loss: 2.9546
# Epoch 42:
# [MODEL SAVED]
# Training accuracy: 11.77%, loss: 2.8673
# Validaion accuracy: 12.35%, loss: 2.9481
# Epoch 43:
# [MODEL SAVED]
# Training accuracy: 11.56%, loss: 2.8464
# Validaion accuracy: 12.35%, loss: 2.9410
# Epoch 44:
# [MODEL SAVED]
# Training accuracy: 12.09%, loss: 2.7652
# Validaion accuracy: 12.35%, loss: 2.9340
# Epoch 45:
# [MODEL SAVED]
# Training accuracy: 12.20%, loss: 2.7968
# Validaion accuracy: 12.35%, loss: 2.9285
# Epoch 46:
# [MODEL SAVED]
# Training accuracy: 11.76%, loss: 2.8446
# Validaion accuracy: 12.35%, loss: 2.9212
# Epoch 47:
# [MODEL SAVED]
# Training accuracy: 12.52%, loss: 2.8462
# Validaion accuracy: 12.51%, loss: 2.9149
# Epoch 48:
# [MODEL SAVED]
# Training accuracy: 10.94%, loss: 2.8578
# Validaion accuracy: 12.51%, loss: 2.9110
# Epoch 49:
# [MODEL SAVED]
# Training accuracy: 12.78%, loss: 2.7825
# Validaion accuracy: 12.51%, loss: 2.9074
# Epoch 50:
# [MODEL SAVED]
# Training accuracy: 12.46%, loss: 2.8301
# Validaion accuracy: 12.67%, loss: 2.9001
# Epoch 51:
# [MODEL SAVED]
# Training accuracy: 13.25%, loss: 2.8468
# Validaion accuracy: 12.67%, loss: 2.8948
# Epoch 52:
# [MODEL SAVED]
# Training accuracy: 12.49%, loss: 2.8480
# Validaion accuracy: 12.51%, loss: 2.8911
# Epoch 53:
# [MODEL SAVED]
# Training accuracy: 11.83%, loss: 2.8601
# Validaion accuracy: 12.51%, loss: 2.8860
# Epoch 54:
# [MODEL SAVED]
# Training accuracy: 12.61%, loss: 2.7460
# Validaion accuracy: 12.67%, loss: 2.8815
# Epoch 55:
# [MODEL SAVED]
# Training accuracy: 12.92%, loss: 2.7404
# Validaion accuracy: 12.51%, loss: 2.8785
# Epoch 56:
# [MODEL SAVED]
# Training accuracy: 11.97%, loss: 2.7011
# Validaion accuracy: 12.51%, loss: 2.8754
# Epoch 57:
# [MODEL SAVED]
# Training accuracy: 12.51%, loss: 2.6767
# Validaion accuracy: 12.51%, loss: 2.8730
# Epoch 58:
# [MODEL SAVED]
# Training accuracy: 12.91%, loss: 2.6629
# Validaion accuracy: 12.51%, loss: 2.8702
# Epoch 59:
# [MODEL SAVED]
# Training accuracy: 12.78%, loss: 2.7209
# Validaion accuracy: 12.51%, loss: 2.8673
# Epoch 60:
# [MODEL SAVED]
# Training accuracy: 11.41%, loss: 2.8699
# Validaion accuracy: 12.51%, loss: 2.8643
# Epoch 61:
# [MODEL SAVED]
# Training accuracy: 11.64%, loss: 2.8390
# Validaion accuracy: 12.51%, loss: 2.8618
# Epoch 62:
# [MODEL SAVED]
# Training accuracy: 11.39%, loss: 2.7716
# Validaion accuracy: 12.67%, loss: 2.8602
# Epoch 63:
# [MODEL SAVED]
# Training accuracy: 12.27%, loss: 2.7232
# Validaion accuracy: 12.67%, loss: 2.8583
# Epoch 64:
# [MODEL SAVED]
# Training accuracy: 13.64%, loss: 2.6730
# Validaion accuracy: 12.67%, loss: 2.8564
# Epoch 65:
# [MODEL SAVED]
# Training accuracy: 12.04%, loss: 2.7986
# Validaion accuracy: 12.95%, loss: 2.8554
# Epoch 66:
# [MODEL SAVED]
# Training accuracy: 13.68%, loss: 2.7219
# Validaion accuracy: 12.95%, loss: 2.8541
# Epoch 67:
# [MODEL SAVED]
# Training accuracy: 12.14%, loss: 2.7570
# Validaion accuracy: 12.79%, loss: 2.8518
# Epoch 68:
# [MODEL SAVED]
# Training accuracy: 12.11%, loss: 2.7292
# Validaion accuracy: 12.79%, loss: 2.8513
# Epoch 69:
# [MODEL SAVED]
# Training accuracy: 12.64%, loss: 2.6536
# Validaion accuracy: 12.79%, loss: 2.8498
# Epoch 70:
# [MODEL SAVED]
# Training accuracy: 11.67%, loss: 2.7201
# Validaion accuracy: 12.95%, loss: 2.8483
# Epoch 71:
# [MODEL SAVED]
# Training accuracy: 11.63%, loss: 2.6591
# Validaion accuracy: 12.79%, loss: 2.8475
# Epoch 72:
# [MODEL SAVED]
# Training accuracy: 12.71%, loss: 2.7149
# Validaion accuracy: 12.79%, loss: 2.8466
# Epoch 73:
# [MODEL SAVED]
# Training accuracy: 11.54%, loss: 2.7137
# Validaion accuracy: 12.79%, loss: 2.8449
# Epoch 74:
# [MODEL SAVED]
# Training accuracy: 13.09%, loss: 2.6889
# Validaion accuracy: 12.79%, loss: 2.8444
# Epoch 75:
# [MODEL SAVED]
# Training accuracy: 11.87%, loss: 2.7428
# Validaion accuracy: 12.79%, loss: 2.8429
# Epoch 76:
# [MODEL SAVED]
# Training accuracy: 13.32%, loss: 2.6532
# Validaion accuracy: 12.79%, loss: 2.8418
# Epoch 77:
# [MODEL SAVED]
# Training accuracy: 11.99%, loss: 2.7249
# Validaion accuracy: 12.79%, loss: 2.8410
# Epoch 78:
# [MODEL SAVED]
# Training accuracy: 12.88%, loss: 2.7171
# Validaion accuracy: 12.79%, loss: 2.8399
# Epoch 79:
# [MODEL SAVED]
# Training accuracy: 12.29%, loss: 2.6985
# Validaion accuracy: 12.79%, loss: 2.8388
# Epoch 80:
# [MODEL SAVED]
# Training accuracy: 13.49%, loss: 2.6500
# Validaion accuracy: 12.79%, loss: 2.8378

# %%
bs_cand = [8, 16, 100]
train_acc = []
valid_acc = []

for bs in bs_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=bs)
  valid_dataloader = Dataloader(valid_dataset, batch_size=bs)
  model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=80, learning_rate=LR, learning_rate_decay=LR_DECAY, verbose=1)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(bs_cand, train_acc, valid_acc)
# Out:
# Training with batch_size=8, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Epoch 1:
# [MODEL SAVED]
# Training accuracy: 14.07%, loss: 6.0724
# Validaion accuracy: 13.84%, loss: 4.5171
# Epoch 2:
# [MODEL SAVED]
# Training accuracy: 17.70%, loss: 3.4112
# Validaion accuracy: 15.15%, loss: 3.4987
# Epoch 3:
# [MODEL SAVED]
# Training accuracy: 18.10%, loss: 2.6977
# Validaion accuracy: 18.76%, loss: 2.5573
# Epoch 4:
# [MODEL SAVED]
# Training accuracy: 17.99%, loss: 2.1728
# Validaion accuracy: 17.16%, loss: 2.1169
# Epoch 5:
# [MODEL SAVED]
# Training accuracy: 18.98%, loss: 1.8040
# Validaion accuracy: 18.49%, loss: 1.8507
# Epoch 6:
# [MODEL SAVED]
# Training accuracy: 18.89%, loss: 1.4995
# Validaion accuracy: 18.41%, loss: 1.5025
# Epoch 7:
# [MODEL SAVED]
# Training accuracy: 20.51%, loss: 1.2826
# Validaion accuracy: 18.71%, loss: 1.3332
# Epoch 8:
# [MODEL SAVED]
# Training accuracy: 21.61%, loss: 1.0694
# Validaion accuracy: 18.33%, loss: 1.1226
# Epoch 9:
# [MODEL SAVED]
# Training accuracy: 20.69%, loss: 0.9239
# Validaion accuracy: 18.22%, loss: 0.9651
# Epoch 10:
# [MODEL SAVED]
# Training accuracy: 21.30%, loss: 0.7988
# Validaion accuracy: 18.96%, loss: 0.8399
# Epoch 11:
# [MODEL SAVED]
# Training accuracy: 21.12%, loss: 0.6925
# Validaion accuracy: 19.88%, loss: 0.7392
# Epoch 12:
# [MODEL SAVED]
# Training accuracy: 22.02%, loss: 0.6122
# Validaion accuracy: 18.73%, loss: 0.6374
# Epoch 13:
# [MODEL SAVED]
# Training accuracy: 24.33%, loss: 0.5262
# Validaion accuracy: 18.09%, loss: 0.5792
# Epoch 14:
# [MODEL SAVED]
# Training accuracy: 22.87%, loss: 0.4857
# Validaion accuracy: 17.01%, loss: 0.5377
# Epoch 15:
# [MODEL SAVED]
# Training accuracy: 24.19%, loss: 0.4480
# Validaion accuracy: 18.49%, loss: 0.4730
# Epoch 16:
# [MODEL SAVED]
# Training accuracy: 24.66%, loss: 0.4109
# Validaion accuracy: 19.21%, loss: 0.4507
# Epoch 17:
# [MODEL SAVED]
# Training accuracy: 24.18%, loss: 0.3920
# Validaion accuracy: 19.40%, loss: 0.4199
# Epoch 18:
# [MODEL SAVED]
# Training accuracy: 25.39%, loss: 0.3675
# Validaion accuracy: 20.20%, loss: 0.4001
# Epoch 19:
# [MODEL SAVED]
# Training accuracy: 25.47%, loss: 0.3594
# Validaion accuracy: 19.45%, loss: 0.3920
# Epoch 20:
# [MODEL SAVED]
# Training accuracy: 24.95%, loss: 0.3489
# Validaion accuracy: 21.24%, loss: 0.3705
# Epoch 21:
# [MODEL SAVED]
# Training accuracy: 24.25%, loss: 0.3282
# Validaion accuracy: 19.11%, loss: 0.3685
# Epoch 22:
# [MODEL SAVED]
# Training accuracy: 26.20%, loss: 0.3394
# Validaion accuracy: 19.24%, loss: 0.3622
# Epoch 23:
# [MODEL SAVED]
# Training accuracy: 26.44%, loss: 0.3210
# Validaion accuracy: 20.88%, loss: 0.3523
# Epoch 24:
# [MODEL SAVED]
# Training accuracy: 26.93%, loss: 0.3229
# Validaion accuracy: 22.45%, loss: 0.3463
# Epoch 25:
# [MODEL SAVED]
# Training accuracy: 26.41%, loss: 0.3155
# Validaion accuracy: 21.85%, loss: 0.3443
# Epoch 26:
# [MODEL SAVED]
# Training accuracy: 25.62%, loss: 0.3269
# Validaion accuracy: 22.07%, loss: 0.3408
# Epoch 27:
# [MODEL SAVED]
# Training accuracy: 25.76%, loss: 0.3140
# Validaion accuracy: 20.33%, loss: 0.3400
# Epoch 28:
# [MODEL SAVED]
# Training accuracy: 26.68%, loss: 0.3131
# Validaion accuracy: 21.63%, loss: 0.3347
# Epoch 29:
# [MODEL SAVED]
# Training accuracy: 26.33%, loss: 0.3135
# Validaion accuracy: 23.09%, loss: 0.3263
# Epoch 30:
# [MODEL SAVED]
# Training accuracy: 26.76%, loss: 0.3094
# Validaion accuracy: 22.45%, loss: 0.3254
# Epoch 31:
# Training accuracy: 27.17%, loss: 0.3032
# Validaion accuracy: 22.39%, loss: 0.3280
# Epoch 32:
# Training accuracy: 26.19%, loss: 0.3103
# Validaion accuracy: 22.88%, loss: 0.3260
# Epoch 33:
# Training accuracy: 26.71%, loss: 0.3046
# Validaion accuracy: 19.76%, loss: 0.3256
# Epoch 34:
# [MODEL SAVED]
# Training accuracy: 26.90%, loss: 0.3037
# Validaion accuracy: 23.48%, loss: 0.3217
# Epoch 35:
# [MODEL SAVED]
# Training accuracy: 26.11%, loss: 0.3027
# Validaion accuracy: 23.14%, loss: 0.3173
# Epoch 36:
# Training accuracy: 25.04%, loss: 0.3072
# Validaion accuracy: 21.48%, loss: 0.3184
# Epoch 37:
# [MODEL SAVED]
# Training accuracy: 26.27%, loss: 0.3100
# Validaion accuracy: 24.10%, loss: 0.3152
# Epoch 38:
# [MODEL SAVED]
# Training accuracy: 27.61%, loss: 0.3044
# Validaion accuracy: 24.76%, loss: 0.3142
# Epoch 39:
# Training accuracy: 26.75%, loss: 0.2983
# Validaion accuracy: 22.47%, loss: 0.3159
# Epoch 40:
# Training accuracy: 26.43%, loss: 0.2971
# Validaion accuracy: 22.17%, loss: 0.3160
# Epoch 41:
# [MODEL SAVED]
# Training accuracy: 27.77%, loss: 0.2989
# Validaion accuracy: 22.89%, loss: 0.3128
# Epoch 42:
# [MODEL SAVED]
# Training accuracy: 25.94%, loss: 0.3018
# Validaion accuracy: 21.95%, loss: 0.3126
# Epoch 43:
# [MODEL SAVED]
# Training accuracy: 25.99%, loss: 0.3023
# Validaion accuracy: 24.81%, loss: 0.3117
# Epoch 44:
# [MODEL SAVED]
# Training accuracy: 26.24%, loss: 0.2972
# Validaion accuracy: 23.01%, loss: 0.3101
# Epoch 45:
# [MODEL SAVED]
# Training accuracy: 26.73%, loss: 0.3000
# Validaion accuracy: 23.17%, loss: 0.3097
# Epoch 46:
# [MODEL SAVED]
# Training accuracy: 26.04%, loss: 0.3036
# Validaion accuracy: 24.61%, loss: 0.3080
# Epoch 47:
# Training accuracy: 25.86%, loss: 0.3029
# Validaion accuracy: 22.93%, loss: 0.3090
# Epoch 48:
# Training accuracy: 25.78%, loss: 0.2904
# Validaion accuracy: 23.31%, loss: 0.3094
# Epoch 49:
# [MODEL SAVED]
# Training accuracy: 26.48%, loss: 0.2956
# Validaion accuracy: 25.16%, loss: 0.3068
# Epoch 50:
# [MODEL SAVED]
# Training accuracy: 26.07%, loss: 0.2958
# Validaion accuracy: 24.49%, loss: 0.3058
# Epoch 51:
# Training accuracy: 26.36%, loss: 0.2913
# Validaion accuracy: 24.90%, loss: 0.3059
# Epoch 52:
# Training accuracy: 26.28%, loss: 0.3009
# Validaion accuracy: 23.09%, loss: 0.3062
# Epoch 53:
# Training accuracy: 25.87%, loss: 0.2984
# Validaion accuracy: 24.04%, loss: 0.3065
# Epoch 54:
# Training accuracy: 25.46%, loss: 0.2993
# Validaion accuracy: 21.19%, loss: 0.3084
# Epoch 55:
# Training accuracy: 26.01%, loss: 0.2964
# Validaion accuracy: 21.64%, loss: 0.3081
# Epoch 56:
# [MODEL SAVED]
# Training accuracy: 26.61%, loss: 0.2947
# Validaion accuracy: 24.19%, loss: 0.3040
# Epoch 57:
# Training accuracy: 26.40%, loss: 0.2909
# Validaion accuracy: 23.22%, loss: 0.3054
# Epoch 58:
# [MODEL SAVED]
# Training accuracy: 26.04%, loss: 0.2885
# Validaion accuracy: 24.26%, loss: 0.3034
# Epoch 59:
# Training accuracy: 25.38%, loss: 0.2995
# Validaion accuracy: 24.41%, loss: 0.3036
# Epoch 60:
# [MODEL SAVED]
# Training accuracy: 26.58%, loss: 0.2967
# Validaion accuracy: 25.13%, loss: 0.3029
# Epoch 61:
# Training accuracy: 25.88%, loss: 0.2974
# Validaion accuracy: 23.16%, loss: 0.3041
# Epoch 62:
# Training accuracy: 25.75%, loss: 0.2980
# Validaion accuracy: 24.13%, loss: 0.3031
# Epoch 63:
# [MODEL SAVED]
# Training accuracy: 24.92%, loss: 0.2999
# Validaion accuracy: 24.69%, loss: 0.3024
# Epoch 64:
# [MODEL SAVED]
# Training accuracy: 26.32%, loss: 0.2954
# Validaion accuracy: 24.44%, loss: 0.3018
# Epoch 65:
# Training accuracy: 25.34%, loss: 0.3019
# Validaion accuracy: 24.41%, loss: 0.3027
# Epoch 66:
# Training accuracy: 25.05%, loss: 0.2916
# Validaion accuracy: 24.85%, loss: 0.3024
# Epoch 67:
# Training accuracy: 24.92%, loss: 0.2969
# Validaion accuracy: 23.57%, loss: 0.3018
# Epoch 68:
# [MODEL SAVED]
# Training accuracy: 24.95%, loss: 0.2963
# Validaion accuracy: 25.21%, loss: 0.3010
# Epoch 69:
# Training accuracy: 24.91%, loss: 0.2959
# Validaion accuracy: 24.27%, loss: 0.3017
# Epoch 70:
# Training accuracy: 27.04%, loss: 0.2865
# Validaion accuracy: 25.41%, loss: 0.3012
# Epoch 71:
# [MODEL SAVED]
# Training accuracy: 25.79%, loss: 0.2836
# Validaion accuracy: 25.32%, loss: 0.3009
# Epoch 72:
# Training accuracy: 24.96%, loss: 0.2895
# Validaion accuracy: 23.63%, loss: 0.3018
# Epoch 73:
# [MODEL SAVED]
# Training accuracy: 26.14%, loss: 0.2903
# Validaion accuracy: 25.00%, loss: 0.3002
# Epoch 74:
# Training accuracy: 25.97%, loss: 0.2991
# Validaion accuracy: 24.85%, loss: 0.3014
# Epoch 75:
# Training accuracy: 26.04%, loss: 0.2982
# Validaion accuracy: 24.58%, loss: 0.3011
# Epoch 76:
# [MODEL SAVED]
# Training accuracy: 27.32%, loss: 0.2824
# Validaion accuracy: 25.40%, loss: 0.3001
# Epoch 77:
# Training accuracy: 25.73%, loss: 0.2926
# Validaion accuracy: 25.37%, loss: 0.3003
# Epoch 78:
# Training accuracy: 25.60%, loss: 0.2935
# Validaion accuracy: 24.52%, loss: 0.3012
# Epoch 79:
# Training accuracy: 26.42%, loss: 0.2933
# Validaion accuracy: 24.36%, loss: 0.3004
# Epoch 80:
# Training accuracy: 25.93%, loss: 0.2962
# Validaion accuracy: 25.38%, loss: 0.3006
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Epoch 1:
# [MODEL SAVED]
# Training accuracy: 10.91%, loss: nan
# Validaion accuracy: 11.15%, loss: 3.5118
# Epoch 2:
# [MODEL SAVED]
# Training accuracy: 12.37%, loss: 2.9665
# Validaion accuracy: 11.87%, loss: 2.8994
# Epoch 3:
# [MODEL SAVED]
# Training accuracy: 15.23%, loss: 2.5204
# Validaion accuracy: 14.57%, loss: 2.5092
# Epoch 4:
# [MODEL SAVED]
# Training accuracy: 15.10%, loss: 2.1824
# Validaion accuracy: 14.69%, loss: 2.2869
# Epoch 5:
# [MODEL SAVED]
# Training accuracy: 14.55%, loss: 2.0794
# Validaion accuracy: 17.57%, loss: 2.1231
# Epoch 6:
# [MODEL SAVED]
# Training accuracy: 15.72%, loss: 1.8861
# Validaion accuracy: 15.71%, loss: 2.0268
# Epoch 7:
# [MODEL SAVED]
# Training accuracy: 17.04%, loss: 1.7535
# Validaion accuracy: 15.44%, loss: 1.8990
# Epoch 8:
# [MODEL SAVED]
# Training accuracy: 17.02%, loss: 1.6831
# Validaion accuracy: 16.65%, loss: 1.7997
# Epoch 9:
# [MODEL SAVED]
# Training accuracy: 17.37%, loss: 1.5705
# Validaion accuracy: 15.21%, loss: 1.7382
# Epoch 10:
# [MODEL SAVED]
# Training accuracy: 16.21%, loss: 1.5196
# Validaion accuracy: 15.32%, loss: 1.6505
# Epoch 11:
# [MODEL SAVED]
# Training accuracy: 17.35%, loss: 1.4678
# Validaion accuracy: 15.85%, loss: 1.5778
# Epoch 12:
# [MODEL SAVED]
# Training accuracy: 16.22%, loss: 1.3845
# Validaion accuracy: 15.37%, loss: 1.5391
# Epoch 13:
# [MODEL SAVED]
# Training accuracy: 17.92%, loss: 1.3139
# Validaion accuracy: 16.33%, loss: 1.4853
# Epoch 14:
# [MODEL SAVED]
# Training accuracy: 17.01%, loss: 1.2936
# Validaion accuracy: 15.69%, loss: 1.4536
# Epoch 15:
# [MODEL SAVED]
# Training accuracy: 16.86%, loss: 1.3054
# Validaion accuracy: 16.57%, loss: 1.3913
# Epoch 16:
# [MODEL SAVED]
# Training accuracy: 17.75%, loss: 1.1892
# Validaion accuracy: 16.49%, loss: 1.3402
# Epoch 17:
# [MODEL SAVED]
# Training accuracy: 15.81%, loss: 1.2687
# Validaion accuracy: 16.41%, loss: 1.3057
# Epoch 18:
# [MODEL SAVED]
# Training accuracy: 18.71%, loss: 1.1783
# Validaion accuracy: 17.04%, loss: 1.2708
# Epoch 19:
# [MODEL SAVED]
# Training accuracy: 16.62%, loss: 1.1538
# Validaion accuracy: 18.25%, loss: 1.2416
# Epoch 20:
# [MODEL SAVED]
# Training accuracy: 18.00%, loss: 1.1066
# Validaion accuracy: 18.41%, loss: 1.2063
# Epoch 21:
# [MODEL SAVED]
# Training accuracy: 17.18%, loss: 1.0969
# Validaion accuracy: 17.29%, loss: 1.1804
# Epoch 22:
# [MODEL SAVED]
# Training accuracy: 16.76%, loss: 1.0878
# Validaion accuracy: 17.77%, loss: 1.1421
# Epoch 23:
# [MODEL SAVED]
# Training accuracy: 17.12%, loss: 1.0641
# Validaion accuracy: 18.25%, loss: 1.1227
# Epoch 24:
# [MODEL SAVED]
# Training accuracy: 18.33%, loss: 1.0220
# Validaion accuracy: 17.45%, loss: 1.1034
# Epoch 25:
# [MODEL SAVED]
# Training accuracy: 17.21%, loss: 1.0083
# Validaion accuracy: 17.20%, loss: 1.0920
# Epoch 26:
# [MODEL SAVED]
# Training accuracy: 18.40%, loss: 0.9769
# Validaion accuracy: 17.04%, loss: 1.0749
# Epoch 27:
# [MODEL SAVED]
# Training accuracy: 17.20%, loss: 0.9608
# Validaion accuracy: 16.81%, loss: 1.0548
# Epoch 28:
# [MODEL SAVED]
# Training accuracy: 18.58%, loss: 0.9610
# Validaion accuracy: 17.57%, loss: 1.0390
# Epoch 29:
# [MODEL SAVED]
# Training accuracy: 16.81%, loss: 0.9574
# Validaion accuracy: 17.29%, loss: 1.0259
# Epoch 30:
# [MODEL SAVED]
# Training accuracy: 17.65%, loss: 0.9296
# Validaion accuracy: 16.56%, loss: 1.0192
# Epoch 31:
# [MODEL SAVED]
# Training accuracy: 18.64%, loss: 0.9315
# Validaion accuracy: 16.97%, loss: 1.0003
# Epoch 32:
# [MODEL SAVED]
# Training accuracy: 18.98%, loss: 0.9078
# Validaion accuracy: 16.88%, loss: 0.9874
# Epoch 33:
# [MODEL SAVED]
# Training accuracy: 18.00%, loss: 0.8909
# Validaion accuracy: 17.78%, loss: 0.9758
# Epoch 34:
# [MODEL SAVED]
# Training accuracy: 19.04%, loss: 0.8653
# Validaion accuracy: 17.04%, loss: 0.9599
# Epoch 35:
# [MODEL SAVED]
# Training accuracy: 17.29%, loss: 0.8956
# Validaion accuracy: 17.29%, loss: 0.9591
# Epoch 36:
# [MODEL SAVED]
# Training accuracy: 17.58%, loss: 0.8946
# Validaion accuracy: 17.50%, loss: 0.9426
# Epoch 37:
# [MODEL SAVED]
# Training accuracy: 18.99%, loss: 0.8670
# Validaion accuracy: 18.09%, loss: 0.9369
# Epoch 38:
# [MODEL SAVED]
# Training accuracy: 17.83%, loss: 0.8451
# Validaion accuracy: 17.45%, loss: 0.9275
# Epoch 39:
# [MODEL SAVED]
# Training accuracy: 17.94%, loss: 0.8470
# Validaion accuracy: 17.18%, loss: 0.9201
# Epoch 40:
# [MODEL SAVED]
# Training accuracy: 19.00%, loss: 0.8343
# Validaion accuracy: 17.61%, loss: 0.9087
# Epoch 41:
# Training accuracy: 18.34%, loss: 0.8219
# Validaion accuracy: 17.67%, loss: 0.9108
# Epoch 42:
# [MODEL SAVED]
# Training accuracy: 16.26%, loss: 0.8599
# Validaion accuracy: 16.88%, loss: 0.9023
# Epoch 43:
# [MODEL SAVED]
# Training accuracy: 18.37%, loss: 0.8290
# Validaion accuracy: 17.05%, loss: 0.8938
# Epoch 44:
# [MODEL SAVED]
# Training accuracy: 18.30%, loss: 0.8329
# Validaion accuracy: 17.68%, loss: 0.8926
# Epoch 45:
# [MODEL SAVED]
# Training accuracy: 19.73%, loss: 0.8002
# Validaion accuracy: 17.77%, loss: 0.8789
# Epoch 46:
# [MODEL SAVED]
# Training accuracy: 17.95%, loss: 0.8162
# Validaion accuracy: 17.78%, loss: 0.8771
# Epoch 47:
# [MODEL SAVED]
# Training accuracy: 16.92%, loss: 0.8228
# Validaion accuracy: 17.61%, loss: 0.8711
# Epoch 48:
# [MODEL SAVED]
# Training accuracy: 17.26%, loss: 0.7922
# Validaion accuracy: 17.20%, loss: 0.8694
# Epoch 49:
# Training accuracy: 18.41%, loss: 0.7968
# Validaion accuracy: 17.58%, loss: 0.8704
# Epoch 50:
# [MODEL SAVED]
# Training accuracy: 17.64%, loss: 0.8059
# Validaion accuracy: 17.45%, loss: 0.8599
# Epoch 51:
# [MODEL SAVED]
# Training accuracy: 17.89%, loss: 0.7893
# Validaion accuracy: 17.78%, loss: 0.8580
# Epoch 52:
# [MODEL SAVED]
# Training accuracy: 18.27%, loss: 0.8017
# Validaion accuracy: 18.39%, loss: 0.8520
# Epoch 53:
# [MODEL SAVED]
# Training accuracy: 18.32%, loss: 0.7948
# Validaion accuracy: 17.32%, loss: 0.8507
# Epoch 54:
# [MODEL SAVED]
# Training accuracy: 18.12%, loss: 0.7783
# Validaion accuracy: 17.61%, loss: 0.8472
# Epoch 55:
# [MODEL SAVED]
# Training accuracy: 17.62%, loss: 0.7871
# Validaion accuracy: 17.61%, loss: 0.8472
# Epoch 56:
# [MODEL SAVED]
# Training accuracy: 18.20%, loss: 0.7697
# Validaion accuracy: 17.77%, loss: 0.8431
# Epoch 57:
# [MODEL SAVED]
# Training accuracy: 17.53%, loss: 0.7565
# Validaion accuracy: 17.84%, loss: 0.8408
# Epoch 58:
# Training accuracy: 19.07%, loss: 0.7487
# Validaion accuracy: 16.75%, loss: 0.8408
# Epoch 59:
# [MODEL SAVED]
# Training accuracy: 16.93%, loss: 0.7835
# Validaion accuracy: 17.34%, loss: 0.8351
# Epoch 60:
# [MODEL SAVED]
# Training accuracy: 18.24%, loss: 0.7770
# Validaion accuracy: 17.80%, loss: 0.8319
# Epoch 61:
# [MODEL SAVED]
# Training accuracy: 16.28%, loss: 0.7835
# Validaion accuracy: 17.43%, loss: 0.8298
# Epoch 62:
# Training accuracy: 16.77%, loss: 0.7911
# Validaion accuracy: 17.71%, loss: 0.8298
# Epoch 63:
# [MODEL SAVED]
# Training accuracy: 19.63%, loss: 0.7507
# Validaion accuracy: 17.66%, loss: 0.8282
# Epoch 64:
# [MODEL SAVED]
# Training accuracy: 20.17%, loss: 0.7343
# Validaion accuracy: 18.07%, loss: 0.8261
# Epoch 65:
# [MODEL SAVED]
# Training accuracy: 18.16%, loss: 0.7785
# Validaion accuracy: 17.07%, loss: 0.8250
# Epoch 66:
# [MODEL SAVED]
# Training accuracy: 17.24%, loss: 0.7566
# Validaion accuracy: 17.55%, loss: 0.8240
# Epoch 67:
# [MODEL SAVED]
# Training accuracy: 17.98%, loss: 0.7655
# Validaion accuracy: 17.71%, loss: 0.8208
# Epoch 68:
# [MODEL SAVED]
# Training accuracy: 18.00%, loss: 0.7472
# Validaion accuracy: 17.55%, loss: 0.8204
# Epoch 69:
# Training accuracy: 17.33%, loss: 0.7469
# Validaion accuracy: 17.23%, loss: 0.8205
# Epoch 70:
# [MODEL SAVED]
# Training accuracy: 17.43%, loss: 0.7304
# Validaion accuracy: 17.39%, loss: 0.8180
# Epoch 71:
# [MODEL SAVED]
# Training accuracy: 17.41%, loss: 0.7288
# Validaion accuracy: 17.50%, loss: 0.8176
# Epoch 72:
# [MODEL SAVED]
# Training accuracy: 18.17%, loss: 0.7358
# Validaion accuracy: 17.39%, loss: 0.8157
# Epoch 73:
# [MODEL SAVED]
# Training accuracy: 18.61%, loss: 0.7306
# Validaion accuracy: 18.11%, loss: 0.8108
# Epoch 74:
# Training accuracy: 17.64%, loss: 0.7650
# Validaion accuracy: 17.87%, loss: 0.8112
# Epoch 75:
# [MODEL SAVED]
# Training accuracy: 18.54%, loss: 0.7561
# Validaion accuracy: 17.55%, loss: 0.8097
# Epoch 76:
# Training accuracy: 17.64%, loss: 0.7209
# Validaion accuracy: 18.14%, loss: 0.8098
# Epoch 77:
# Training accuracy: 17.44%, loss: 0.7339
# Validaion accuracy: 17.87%, loss: 0.8101
# Epoch 78:
# Training accuracy: 18.85%, loss: 0.7393
# Validaion accuracy: 17.55%, loss: 0.8099
# Epoch 79:
# [MODEL SAVED]
# Training accuracy: 18.81%, loss: 0.7397
# Validaion accuracy: 17.87%, loss: 0.8082
# Epoch 80:
# [MODEL SAVED]
# Training accuracy: 18.72%, loss: 0.7465
# Validaion accuracy: 17.55%, loss: 0.8070
# Training with batch_size=100, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Epoch 1:
# [MODEL SAVED]
# Training accuracy: 8.99%, loss: nan
# Validaion accuracy: 11.17%, loss: 1.7429
# Epoch 2:
# [MODEL SAVED]
# Training accuracy: 10.91%, loss: 1.4573
# Validaion accuracy: 11.21%, loss: 1.4882
# Epoch 3:
# [MODEL SAVED]
# Training accuracy: 10.09%, loss: 1.2404
# Validaion accuracy: 9.15%, loss: 1.3494
# Epoch 4:
# [MODEL SAVED]
# Training accuracy: 9.44%, loss: 1.1821
# Validaion accuracy: 9.70%, loss: 1.2544
# Epoch 5:
# [MODEL SAVED]
# Training accuracy: 10.23%, loss: 1.1879
# Validaion accuracy: 7.95%, loss: 1.1680
# Epoch 6:
# [MODEL SAVED]
# Training accuracy: 12.17%, loss: 1.0465
# Validaion accuracy: 7.95%, loss: 1.0970
# Epoch 7:
# [MODEL SAVED]
# Training accuracy: 10.93%, loss: 0.9323
# Validaion accuracy: 8.08%, loss: 1.0490
# Epoch 8:
# [MODEL SAVED]
# Training accuracy: 9.53%, loss: 1.0474
# Validaion accuracy: 6.39%, loss: 1.0074
# Epoch 9:
# [MODEL SAVED]
# Training accuracy: 6.31%, loss: 0.9909
# Validaion accuracy: 6.04%, loss: 0.9760
# Epoch 10:
# [MODEL SAVED]
# Training accuracy: 11.55%, loss: 0.9531
# Validaion accuracy: 6.20%, loss: 0.9449
# Epoch 11:
# [MODEL SAVED]
# Training accuracy: 8.74%, loss: 0.9632
# Validaion accuracy: 8.61%, loss: 0.9188
# Epoch 12:
# [MODEL SAVED]
# Training accuracy: 10.60%, loss: 0.8412
# Validaion accuracy: 6.91%, loss: 0.8988
# Epoch 13:
# [MODEL SAVED]
# Training accuracy: 9.45%, loss: 0.8290
# Validaion accuracy: 6.85%, loss: 0.8837
# Epoch 14:
# [MODEL SAVED]
# Training accuracy: 12.97%, loss: 0.8153
# Validaion accuracy: 7.55%, loss: 0.8718
# Epoch 15:
# [MODEL SAVED]
# Training accuracy: 10.17%, loss: 0.7999
# Validaion accuracy: 7.49%, loss: 0.8597
# Epoch 16:
# [MODEL SAVED]
# Training accuracy: 11.33%, loss: 0.8241
# Validaion accuracy: 7.49%, loss: 0.8471
# Epoch 17:
# [MODEL SAVED]
# Training accuracy: 9.85%, loss: 0.9060
# Validaion accuracy: 7.49%, loss: 0.8323
# Epoch 18:
# [MODEL SAVED]
# Training accuracy: 8.85%, loss: 0.8270
# Validaion accuracy: 7.49%, loss: 0.8233
# Epoch 19:
# [MODEL SAVED]
# Training accuracy: 9.75%, loss: 0.8149
# Validaion accuracy: 8.08%, loss: 0.8110
# Epoch 20:
# [MODEL SAVED]
# Training accuracy: 11.97%, loss: 0.7744
# Validaion accuracy: 8.08%, loss: 0.8012
# Epoch 21:
# [MODEL SAVED]
# Training accuracy: 7.90%, loss: 0.8104
# Validaion accuracy: 8.17%, loss: 0.7932
# Epoch 22:
# [MODEL SAVED]
# Training accuracy: 11.76%, loss: 0.8316
# Validaion accuracy: 8.11%, loss: 0.7832
# Epoch 23:
# [MODEL SAVED]
# Training accuracy: 10.92%, loss: 0.7335
# Validaion accuracy: 8.11%, loss: 0.7766
# Epoch 24:
# [MODEL SAVED]
# Training accuracy: 8.39%, loss: 0.7763
# Validaion accuracy: 8.11%, loss: 0.7683
# Epoch 25:
# [MODEL SAVED]
# Training accuracy: 8.42%, loss: 0.7411
# Validaion accuracy: 8.11%, loss: 0.7604
# Epoch 26:
# [MODEL SAVED]
# Training accuracy: 9.21%, loss: 0.7398
# Validaion accuracy: 8.11%, loss: 0.7543
# Epoch 27:
# [MODEL SAVED]
# Training accuracy: 8.17%, loss: 0.7934
# Validaion accuracy: 8.08%, loss: 0.7475
# Epoch 28:
# [MODEL SAVED]
# Training accuracy: 10.27%, loss: 0.7128
# Validaion accuracy: 8.11%, loss: 0.7410
# Epoch 29:
# [MODEL SAVED]
# Training accuracy: 7.80%, loss: 0.7409
# Validaion accuracy: 9.05%, loss: 0.7354
# Epoch 30:
# [MODEL SAVED]
# Training accuracy: 11.85%, loss: 0.6840
# Validaion accuracy: 9.05%, loss: 0.7309
# Epoch 31:
# [MODEL SAVED]
# Training accuracy: 8.89%, loss: 0.7365
# Validaion accuracy: 9.05%, loss: 0.7249
# Epoch 32:
# [MODEL SAVED]
# Training accuracy: 10.25%, loss: 0.6509
# Validaion accuracy: 9.05%, loss: 0.7198
# Epoch 33:
# [MODEL SAVED]
# Training accuracy: 11.31%, loss: 0.7218
# Validaion accuracy: 9.05%, loss: 0.7164
# Epoch 34:
# [MODEL SAVED]
# Training accuracy: 11.42%, loss: 0.7015
# Validaion accuracy: 10.40%, loss: 0.7105
# Epoch 35:
# [MODEL SAVED]
# Training accuracy: 8.69%, loss: 0.7157
# Validaion accuracy: 9.02%, loss: 0.7076
# Epoch 36:
# [MODEL SAVED]
# Training accuracy: 8.87%, loss: 0.7218
# Validaion accuracy: 10.40%, loss: 0.7035
# Epoch 37:
# [MODEL SAVED]
# Training accuracy: 8.56%, loss: 0.6896
# Validaion accuracy: 10.40%, loss: 0.6997
# Epoch 38:
# [MODEL SAVED]
# Training accuracy: 9.57%, loss: 0.6455
# Validaion accuracy: 9.75%, loss: 0.6973
# Epoch 39:
# [MODEL SAVED]
# Training accuracy: 12.43%, loss: 0.6543
# Validaion accuracy: 9.76%, loss: 0.6938
# Epoch 40:
# [MODEL SAVED]
# Training accuracy: 11.14%, loss: 0.6806
# Validaion accuracy: 9.76%, loss: 0.6903
# Epoch 41:
# [MODEL SAVED]
# Training accuracy: 9.77%, loss: 0.6340
# Validaion accuracy: 9.76%, loss: 0.6880
# Epoch 42:
# [MODEL SAVED]
# Training accuracy: 11.12%, loss: 0.6592
# Validaion accuracy: 9.76%, loss: 0.6860
# Epoch 43:
# [MODEL SAVED]
# Training accuracy: 10.30%, loss: 0.6451
# Validaion accuracy: 9.76%, loss: 0.6842
# Epoch 44:
# [MODEL SAVED]
# Training accuracy: 8.76%, loss: 0.6555
# Validaion accuracy: 9.76%, loss: 0.6814
# Epoch 45:
# [MODEL SAVED]
# Training accuracy: 10.95%, loss: 0.6628
# Validaion accuracy: 9.76%, loss: 0.6794
# Epoch 46:
# [MODEL SAVED]
# Training accuracy: 9.65%, loss: 0.6212
# Validaion accuracy: 9.76%, loss: 0.6776
# Epoch 47:
# [MODEL SAVED]
# Training accuracy: 11.78%, loss: 0.6869
# Validaion accuracy: 9.76%, loss: 0.6760
# Epoch 48:
# [MODEL SAVED]
# Training accuracy: 8.41%, loss: 0.6881
# Validaion accuracy: 9.76%, loss: 0.6739
# Epoch 49:
# [MODEL SAVED]
# Training accuracy: 8.03%, loss: 0.6764
# Validaion accuracy: 9.76%, loss: 0.6719
# Epoch 50:
# [MODEL SAVED]
# Training accuracy: 10.97%, loss: 0.6349
# Validaion accuracy: 9.76%, loss: 0.6703
# Epoch 51:
# [MODEL SAVED]
# Training accuracy: 10.75%, loss: 0.6544
# Validaion accuracy: 9.76%, loss: 0.6687
# Epoch 52:
# [MODEL SAVED]
# Training accuracy: 8.73%, loss: 0.6452
# Validaion accuracy: 9.76%, loss: 0.6674
# Epoch 53:
# [MODEL SAVED]
# Training accuracy: 11.33%, loss: 0.6363
# Validaion accuracy: 9.76%, loss: 0.6664
# Epoch 54:
# [MODEL SAVED]
# Training accuracy: 8.72%, loss: 0.6493
# Validaion accuracy: 9.76%, loss: 0.6652
# Epoch 55:
# [MODEL SAVED]
# Training accuracy: 9.67%, loss: 0.6324
# Validaion accuracy: 9.76%, loss: 0.6643
# Epoch 56:
# [MODEL SAVED]
# Training accuracy: 6.93%, loss: 0.6567
# Validaion accuracy: 9.76%, loss: 0.6633
# Epoch 57:
# [MODEL SAVED]
# Training accuracy: 12.02%, loss: 0.6458
# Validaion accuracy: 9.76%, loss: 0.6624
# Epoch 58:
# [MODEL SAVED]
# Training accuracy: 10.39%, loss: 0.6403
# Validaion accuracy: 9.76%, loss: 0.6617
# Epoch 59:
# [MODEL SAVED]
# Training accuracy: 9.80%, loss: 0.6461
# Validaion accuracy: 9.76%, loss: 0.6605
# Epoch 60:
# [MODEL SAVED]
# Training accuracy: 8.17%, loss: 0.7061
# Validaion accuracy: 9.76%, loss: 0.6593
# Epoch 61:
# [MODEL SAVED]
# Training accuracy: 10.55%, loss: 0.6654
# Validaion accuracy: 9.06%, loss: 0.6586
# Epoch 62:
# [MODEL SAVED]
# Training accuracy: 10.98%, loss: 0.6256
# Validaion accuracy: 9.42%, loss: 0.6580
# Epoch 63:
# [MODEL SAVED]
# Training accuracy: 6.11%, loss: 0.6815
# Validaion accuracy: 9.42%, loss: 0.6571
# Epoch 64:
# [MODEL SAVED]
# Training accuracy: 9.22%, loss: 0.6225
# Validaion accuracy: 9.06%, loss: 0.6564
# Epoch 65:
# [MODEL SAVED]
# Training accuracy: 10.46%, loss: 0.6733
# Validaion accuracy: 9.06%, loss: 0.6556
# Epoch 66:
# [MODEL SAVED]
# Training accuracy: 8.79%, loss: 0.6345
# Validaion accuracy: 9.06%, loss: 0.6550
# Epoch 67:
# [MODEL SAVED]
# Training accuracy: 9.85%, loss: 0.6542
# Validaion accuracy: 9.06%, loss: 0.6543
# Epoch 68:
# [MODEL SAVED]
# Training accuracy: 7.09%, loss: 0.6250
# Validaion accuracy: 9.42%, loss: 0.6539
# Epoch 69:
# [MODEL SAVED]
# Training accuracy: 12.42%, loss: 0.6118
# Validaion accuracy: 9.42%, loss: 0.6535
# Epoch 70:
# [MODEL SAVED]
# Training accuracy: 8.36%, loss: 0.6579
# Validaion accuracy: 9.06%, loss: 0.6530
# Epoch 71:
# [MODEL SAVED]
# Training accuracy: 6.98%, loss: 0.6487
# Validaion accuracy: 9.06%, loss: 0.6526
# Epoch 72:
# [MODEL SAVED]
# Training accuracy: 10.47%, loss: 0.6693
# Validaion accuracy: 9.06%, loss: 0.6519
# Epoch 73:
# [MODEL SAVED]
# Training accuracy: 10.41%, loss: 0.6484
# Validaion accuracy: 9.06%, loss: 0.6514
# Epoch 74:
# [MODEL SAVED]
# Training accuracy: 10.16%, loss: 0.6272
# Validaion accuracy: 9.06%, loss: 0.6511
# Epoch 75:
# [MODEL SAVED]
# Training accuracy: 8.33%, loss: 0.6586
# Validaion accuracy: 9.06%, loss: 0.6507
# Epoch 76:
# [MODEL SAVED]
# Training accuracy: 9.58%, loss: 0.6256
# Validaion accuracy: 9.06%, loss: 0.6504
# Epoch 77:
# [MODEL SAVED]
# Training accuracy: 13.11%, loss: 0.6225
# Validaion accuracy: 9.06%, loss: 0.6501
# Epoch 78:
# [MODEL SAVED]
# Training accuracy: 8.88%, loss: 0.6325
# Validaion accuracy: 9.06%, loss: 0.6497
# Epoch 79:
# [MODEL SAVED]
# Training accuracy: 11.01%, loss: 0.6273
# Validaion accuracy: 9.06%, loss: 0.6495
# Epoch 80:
# [MODEL SAVED]
# Training accuracy: 13.08%, loss: 0.6269
# Validaion accuracy: 9.06%, loss: 0.6491

# %%
hd_cand = [32, 64, 256]
train_acc = []
valid_acc = []

for hd in hd_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
  valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
  model = Classifier(IN_DIM, hd, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=80, learning_rate=LR, learning_rate_decay=LR_DECAY, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(hd_cand, train_acc, valid_acc)
# Out:
# Training with batch_size=16, hidden_dim=32, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=256, learning_rate=0.001, learning_rate_decay=0.95

# %%
lr_decay_cand = [1.0, 0.95, 0.9]
train_acc = []
valid_acc = []

for lrd in lr_decay_cand:
  train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
  valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
  model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
  _, ta, _, va = model.training(train_dataloader, valid_dataloader, epochs=80, learning_rate=LR, learning_rate_decay=lrd, verbose=0)
  train_acc.append(ta); valid_acc.append(va)

plot_curves(lr_decay_cand, train_acc, valid_acc)
# Out:
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=1.0
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.95
# Training with batch_size=16, hidden_dim=64, learning_rate=0.001, learning_rate_decay=0.9

# %% [markdown]
# ## Training with Best Hyperparameters

# %%
# Configurations
IN_DIM = np.prod(images[0].shape)
OUT_DIM = len(classes)

# %%
# Please set your hyperparameters here
BATCH_SIZE = 8
LR = 1e-2
LR_DECAY = 1
HIDEEN_DIM = 256

# %%
train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
model = Classifier(IN_DIM, HIDEEN_DIM, OUT_DIM, device=DEVICE)
train_loss, train_acc, valid_loss, valid_acc = model.training(train_dataloader, valid_dataloader, learning_rate=LR, learning_rate_decay=LR_DECAY)
plot_result(train_loss, train_acc, valid_loss, valid_acc)
# Out:
# Training with batch_size=8, hidden_dim=256, learning_rate=0.01, learning_rate_decay=1
# Epoch 1:
# [MODEL SAVED]
# Training accuracy: 40.85%, loss: nan
# Validaion accuracy: 25.48%, loss: 5.0835
# Epoch 2:
# [MODEL SAVED]
# Training accuracy: 47.80%, loss: 1.8464
# Validaion accuracy: 25.11%, loss: 3.7461
# Epoch 3:
# [MODEL SAVED]
# Training accuracy: 47.66%, loss: 1.2958
# Validaion accuracy: 25.53%, loss: 2.0686
# Epoch 4:
# [MODEL SAVED]
# Training accuracy: 49.61%, loss: 0.8192
# Validaion accuracy: 24.61%, loss: 1.5488
# Epoch 5:
# [MODEL SAVED]
# Training accuracy: 51.10%, loss: 0.5432
# Validaion accuracy: 25.18%, loss: 0.9468
# Epoch 6:
# [MODEL SAVED]
# Training accuracy: 54.64%, loss: 0.3678
# Validaion accuracy: 24.09%, loss: 0.7662
# Epoch 7:
# [MODEL SAVED]
# Training accuracy: 56.11%, loss: 0.2846
# Validaion accuracy: 24.21%, loss: 0.5858
# Epoch 8:
# [MODEL SAVED]
# Training accuracy: 58.88%, loss: 0.2425
# Validaion accuracy: 18.98%, loss: 0.5368
# Epoch 9:
# [MODEL SAVED]
# Training accuracy: 59.98%, loss: 0.2152
# Validaion accuracy: 25.33%, loss: 0.4795
# Epoch 10:
# [MODEL SAVED]
# Training accuracy: 60.22%, loss: 0.2092
# Validaion accuracy: 25.53%, loss: 0.4745
# Epoch 11:
# [MODEL SAVED]
# Training accuracy: 60.64%, loss: 0.1988
# Validaion accuracy: 23.40%, loss: 0.4306
# Epoch 12:
# [MODEL SAVED]
# Training accuracy: 60.08%, loss: 0.2007
# Validaion accuracy: 27.57%, loss: 0.4033
# Epoch 13:
# Training accuracy: 60.11%, loss: 0.1940
# Validaion accuracy: 22.04%, loss: 0.4391
# Epoch 14:
# [MODEL SAVED]
# Training accuracy: 59.00%, loss: 0.1928
# Validaion accuracy: 22.97%, loss: 0.3942
# Epoch 15:
# Training accuracy: 59.00%, loss: 0.1918
# Validaion accuracy: 25.94%, loss: 0.3968
# Epoch 16:
# Training accuracy: 58.18%, loss: 0.1946
# Validaion accuracy: 26.02%, loss: 0.3959
# Epoch 17:
# [MODEL SAVED]
# Training accuracy: 56.69%, loss: 0.2016
# Validaion accuracy: 29.13%, loss: 0.3415
# Epoch 18:
# Training accuracy: 56.70%, loss: 0.1923
# Validaion accuracy: 25.31%, loss: 0.3415
# Epoch 19:
# Training accuracy: 56.20%, loss: 0.1935
# Validaion accuracy: 23.17%, loss: 0.3633
# Epoch 20:
# Training accuracy: 55.42%, loss: 0.1938
# Validaion accuracy: 23.75%, loss: 0.3791
# Epoch 21:
# Training accuracy: 55.66%, loss: 0.1950
# Validaion accuracy: 26.54%, loss: 0.3468
# Epoch 22:
# Training accuracy: 54.07%, loss: 0.1968
# Validaion accuracy: 23.78%, loss: 0.3537
# Epoch 23:
# [MODEL SAVED]
# Training accuracy: 53.43%, loss: 0.1978
# Validaion accuracy: 25.03%, loss: 0.3379
# Epoch 24:
# [MODEL SAVED]
# Training accuracy: 52.35%, loss: 0.1968
# Validaion accuracy: 28.65%, loss: 0.3257
# Epoch 25:
# [MODEL SAVED]
# Training accuracy: 53.41%, loss: 0.1957
# Validaion accuracy: 26.93%, loss: 0.3166
# Epoch 26:
# [MODEL SAVED]
# Training accuracy: 53.31%, loss: 0.1905
# Validaion accuracy: 24.21%, loss: 0.3162
# Epoch 27:
# Training accuracy: 52.03%, loss: 0.1975
# Validaion accuracy: 26.24%, loss: 0.3227
# Epoch 28:
# [MODEL SAVED]
# Training accuracy: 50.69%, loss: 0.1983
# Validaion accuracy: 25.48%, loss: 0.3090
# Epoch 29:
# Training accuracy: 51.49%, loss: 0.1938
# Validaion accuracy: 25.37%, loss: 0.3207
# Epoch 30:
# Training accuracy: 52.80%, loss: 0.1921
# Validaion accuracy: 29.01%, loss: 0.3114
# Epoch 31:
# [MODEL SAVED]
# Training accuracy: 51.54%, loss: 0.1953
# Validaion accuracy: 29.25%, loss: 0.2950
# Epoch 32:
# Training accuracy: 50.36%, loss: 0.1998
# Validaion accuracy: 27.01%, loss: 0.3090
# Epoch 33:
# Training accuracy: 50.26%, loss: 0.1988
# Validaion accuracy: 25.41%, loss: 0.3127
# Epoch 34:
# Training accuracy: 51.23%, loss: 0.1936
# Validaion accuracy: 26.73%, loss: 0.3254
# Epoch 35:
# Training accuracy: 50.50%, loss: 0.1953
# Validaion accuracy: 27.04%, loss: 0.3084
# Epoch 36:
# Training accuracy: 50.59%, loss: 0.1950
# Validaion accuracy: 26.97%, loss: 0.3103
# Epoch 37:
# [MODEL SAVED]
# Training accuracy: 51.42%, loss: 0.1917
# Validaion accuracy: 30.38%, loss: 0.2859
# Epoch 38:
# Training accuracy: 51.59%, loss: 0.1893
# Validaion accuracy: 26.98%, loss: 0.3169
# Epoch 39:
# Training accuracy: 51.50%, loss: 0.1929
# Validaion accuracy: 27.74%, loss: 0.3000
# Epoch 40:
# Training accuracy: 51.11%, loss: 0.1933
# Validaion accuracy: 29.86%, loss: 0.2904
# Epoch 41:
# Training accuracy: 51.00%, loss: 0.1899
# Validaion accuracy: 26.37%, loss: 0.3047
# Epoch 42:
# Training accuracy: 50.95%, loss: 0.1929
# Validaion accuracy: 30.21%, loss: 0.2960
# Epoch 43:
# Training accuracy: 50.41%, loss: 0.1918
# Validaion accuracy: 28.83%, loss: 0.2873
# Epoch 44:
# Training accuracy: 51.12%, loss: 0.1903
# Validaion accuracy: 26.86%, loss: 0.2927
# Epoch 45:
# Training accuracy: 50.95%, loss: 0.1926
# Validaion accuracy: 27.56%, loss: 0.2939
# Epoch 46:
# Training accuracy: 51.17%, loss: 0.1905
# Validaion accuracy: 24.21%, loss: 0.3101
# Epoch 47:
# Training accuracy: 51.84%, loss: 0.1882
# Validaion accuracy: 31.00%, loss: 0.2999
# Epoch 48:
# Training accuracy: 51.03%, loss: 0.1894
# Validaion accuracy: 29.28%, loss: 0.2878
# Epoch 49:
# Training accuracy: 51.13%, loss: 0.1881
# Validaion accuracy: 29.37%, loss: 0.2917
# Epoch 50:
# Training accuracy: 51.40%, loss: 0.1902
# Validaion accuracy: 28.31%, loss: 0.2990
# Epoch 51:
# Training accuracy: 50.77%, loss: 0.1911
# Validaion accuracy: 30.29%, loss: 0.2892
# Epoch 52:
# Training accuracy: 51.56%, loss: 0.1904
# Validaion accuracy: 27.82%, loss: 0.2953
# Epoch 53:
# Training accuracy: 51.79%, loss: 0.1858
# Validaion accuracy: 27.86%, loss: 0.3076
# Epoch 54:
# Training accuracy: 51.93%, loss: 0.1895
# Validaion accuracy: 24.18%, loss: 0.3028
# Epoch 55:
# Training accuracy: 51.27%, loss: 0.1896
# Validaion accuracy: 29.44%, loss: 0.2875
# Epoch 56:
# [MODEL SAVED]
# Training accuracy: 52.03%, loss: 0.1854
# Validaion accuracy: 30.06%, loss: 0.2831
# Epoch 57:
# Training accuracy: 50.91%, loss: 0.1879
# Validaion accuracy: 28.02%, loss: 0.2929
# Epoch 58:
# [MODEL SAVED]
# Training accuracy: 50.74%, loss: 0.1892
# Validaion accuracy: 30.42%, loss: 0.2815
# Epoch 59:
# [MODEL SAVED]
# Training accuracy: 51.27%, loss: 0.1893
# Validaion accuracy: 30.98%, loss: 0.2769
# Epoch 60:
# [MODEL SAVED]
# Training accuracy: 51.32%, loss: 0.1862
# Validaion accuracy: 31.25%, loss: 0.2756
# Epoch 61:
# Training accuracy: 51.29%, loss: 0.1841
# Validaion accuracy: 29.60%, loss: 0.2826
# Epoch 62:
# Training accuracy: 51.98%, loss: 0.1867
# Validaion accuracy: 30.39%, loss: 0.2939
# Epoch 63:
# Training accuracy: 51.85%, loss: 0.1880
# Validaion accuracy: 29.56%, loss: 0.2867
# Epoch 64:
# Training accuracy: 51.94%, loss: 0.1843
# Validaion accuracy: 31.18%, loss: 0.2760
# Epoch 65:
# Training accuracy: 51.40%, loss: 0.1884
# Validaion accuracy: 32.07%, loss: 0.2889
# Epoch 66:
# Training accuracy: 51.69%, loss: 0.1880
# Validaion accuracy: 29.54%, loss: 0.2845
# Epoch 67:
# Training accuracy: 51.36%, loss: 0.1874
# Validaion accuracy: 29.40%, loss: 0.3005
# Epoch 68:
# Training accuracy: 51.46%, loss: 0.1856
# Validaion accuracy: 28.39%, loss: 0.2974
# Epoch 69:
# Training accuracy: 52.21%, loss: 0.1841
# Validaion accuracy: 30.24%, loss: 0.2993
# Epoch 70:
# Training accuracy: 52.39%, loss: 0.1833
# Validaion accuracy: 29.86%, loss: 0.2833
# Epoch 71:
# Training accuracy: 52.20%, loss: 0.1842
# Validaion accuracy: 27.97%, loss: 0.2892
# Epoch 72:
# Training accuracy: 51.66%, loss: 0.1879
# Validaion accuracy: 30.47%, loss: 0.2808
# Epoch 73:
# Training accuracy: 52.67%, loss: 0.1845
# Validaion accuracy: 30.21%, loss: 0.2796
# Epoch 74:
# Training accuracy: 52.83%, loss: 0.1831
# Validaion accuracy: 26.70%, loss: 0.2961
# Epoch 75:
# Training accuracy: 52.25%, loss: 0.1836
# Validaion accuracy: 29.66%, loss: 0.2966
# Epoch 76:
# Training accuracy: 52.20%, loss: 0.1857
# Validaion accuracy: 30.46%, loss: 0.2826
# Epoch 77:
# Training accuracy: 51.16%, loss: 0.1863
# Validaion accuracy: 29.30%, loss: 0.2851
# Epoch 78:
# Training accuracy: 52.97%, loss: 0.1825
# Validaion accuracy: 27.77%, loss: 0.3078
# Epoch 79:
# Training accuracy: 52.59%, loss: 0.1828
# Validaion accuracy: 25.38%, loss: 0.3071
# Epoch 80:
# Training accuracy: 51.98%, loss: 0.1860
# Validaion accuracy: 30.20%, loss: 0.3012
# Epoch 81:
# Training accuracy: 52.19%, loss: 0.1854
# Validaion accuracy: 30.22%, loss: 0.2894
# Epoch 82:
# Training accuracy: 53.16%, loss: 0.1832
# Validaion accuracy: 30.69%, loss: 0.2830
# Epoch 83:
# Training accuracy: 52.99%, loss: 0.1830
# Validaion accuracy: 28.94%, loss: 0.2791
# Epoch 84:
# [MODEL SAVED]
# Training accuracy: 52.12%, loss: 0.1827
# Validaion accuracy: 31.34%, loss: 0.2731
# Epoch 85:
# Training accuracy: 53.26%, loss: 0.1805
# Validaion accuracy: 31.17%, loss: 0.2983
# Epoch 86:
# Training accuracy: 51.32%, loss: 0.1853
# Validaion accuracy: 29.83%, loss: 0.2882
# Epoch 87:
# Training accuracy: 52.38%, loss: 0.1852
# Validaion accuracy: 31.72%, loss: 0.2867
# Epoch 88:
# Training accuracy: 52.85%, loss: 0.1826
# Validaion accuracy: 30.22%, loss: 0.2823
# Epoch 89:
# Training accuracy: 53.49%, loss: 0.1805
# Validaion accuracy: 29.28%, loss: 0.2976
# Epoch 90:
# Training accuracy: 52.82%, loss: 0.1822
# Validaion accuracy: 27.81%, loss: 0.3028
# Epoch 91:
# Training accuracy: 53.77%, loss: 0.1791
# Validaion accuracy: 31.69%, loss: 0.2737
# Epoch 92:
# Training accuracy: 51.65%, loss: 0.1846
# Validaion accuracy: 29.79%, loss: 0.2939
# Epoch 93:
# Training accuracy: 53.93%, loss: 0.1780
# Validaion accuracy: 31.23%, loss: 0.2819
# Epoch 94:
# Training accuracy: 51.54%, loss: 0.1843
# Validaion accuracy: 31.75%, loss: 0.2929
# Epoch 95:
# Training accuracy: 52.93%, loss: 0.1809
# Validaion accuracy: 31.56%, loss: 0.2734
# Epoch 96:
# Training accuracy: 52.52%, loss: 0.1820
# Validaion accuracy: 32.76%, loss: 0.2769
# Epoch 97:
# [MODEL SAVED]
# Training accuracy: 52.81%, loss: 0.1810
# Validaion accuracy: 32.38%, loss: 0.2675
# Epoch 98:
# Training accuracy: 52.57%, loss: 0.1818
# Validaion accuracy: 31.86%, loss: 0.2697
# Epoch 99:
# Training accuracy: 53.53%, loss: 0.1790
# Validaion accuracy: 29.70%, loss: 0.2976
# Epoch 100:
# Training accuracy: 52.88%, loss: 0.1818
# Validaion accuracy: 30.32%, loss: 0.2875
# Epoch 101:
# Training accuracy: 53.01%, loss: 0.1832
# Validaion accuracy: 31.53%, loss: 0.2717
# Epoch 102:
# Training accuracy: 53.77%, loss: 0.1782
# Validaion accuracy: 27.76%, loss: 0.2898
# Epoch 103:
# Training accuracy: 54.51%, loss: 0.1743
# Validaion accuracy: 32.79%, loss: 0.2808
# Epoch 104:
# Training accuracy: 52.93%, loss: 0.1805
# Validaion accuracy: 29.75%, loss: 0.2777
# Epoch 105:
# Training accuracy: 53.80%, loss: 0.1775
# Validaion accuracy: 32.22%, loss: 0.2718
# Epoch 106:
# Training accuracy: 52.48%, loss: 0.1803
# Validaion accuracy: 29.95%, loss: 0.2751
# Epoch 107:
# Training accuracy: 53.87%, loss: 0.1791
# Validaion accuracy: 30.32%, loss: 0.2946
# Epoch 108:
# Training accuracy: 52.51%, loss: 0.1815
# Validaion accuracy: 31.64%, loss: 0.2802
# Epoch 109:
# Training accuracy: 51.79%, loss: 0.1832
# Validaion accuracy: 31.81%, loss: 0.2687
# Epoch 110:
# Training accuracy: 53.52%, loss: 0.1798
# Validaion accuracy: 31.69%, loss: 0.2858
# Epoch 111:
# Training accuracy: 52.73%, loss: 0.1821
# Validaion accuracy: 31.54%, loss: 0.2724
# Epoch 112:
# Training accuracy: 52.71%, loss: 0.1792
# Validaion accuracy: 29.42%, loss: 0.3032
# Epoch 113:
# Training accuracy: 52.90%, loss: 0.1781
# Validaion accuracy: 30.23%, loss: 0.2767
# Epoch 114:
# Training accuracy: 53.88%, loss: 0.1767
# Validaion accuracy: 31.42%, loss: 0.2762
# Epoch 115:
# Training accuracy: 53.56%, loss: 0.1779
# Validaion accuracy: 30.20%, loss: 0.2859
# Epoch 116:
# Training accuracy: 54.24%, loss: 0.1780
# Validaion accuracy: 31.40%, loss: 0.2745
# Epoch 117:
# Training accuracy: 53.74%, loss: 0.1799
# Validaion accuracy: 31.54%, loss: 0.2803
# Epoch 118:
# [MODEL SAVED]
# Training accuracy: 53.82%, loss: 0.1787
# Validaion accuracy: 33.60%, loss: 0.2661
# Epoch 119:
# Training accuracy: 54.19%, loss: 0.1774
# Validaion accuracy: 28.17%, loss: 0.3049
# Epoch 120:
# Training accuracy: 53.49%, loss: 0.1811
# Validaion accuracy: 32.34%, loss: 0.2689
# Epoch 121:
# Training accuracy: 55.03%, loss: 0.1747
# Validaion accuracy: 32.04%, loss: 0.2749
# Epoch 122:
# Training accuracy: 54.86%, loss: 0.1749
# Validaion accuracy: 26.26%, loss: 0.3009
# Epoch 123:
# Training accuracy: 54.60%, loss: 0.1734
# Validaion accuracy: 30.81%, loss: 0.3013
# Epoch 124:
# Training accuracy: 54.31%, loss: 0.1777
# Validaion accuracy: 28.53%, loss: 0.2979
# Epoch 125:
# Training accuracy: 53.57%, loss: 0.1782
# Validaion accuracy: 32.77%, loss: 0.2783
# Epoch 126:
# Training accuracy: 54.24%, loss: 0.1768
# Validaion accuracy: 29.77%, loss: 0.2820
# Epoch 127:
# Training accuracy: 54.50%, loss: 0.1735
# Validaion accuracy: 30.56%, loss: 0.2844
# Epoch 128:
# Training accuracy: 55.23%, loss: 0.1713
# Validaion accuracy: 30.84%, loss: 0.2728
# Epoch 129:
# Training accuracy: 54.32%, loss: 0.1745
# Validaion accuracy: 31.69%, loss: 0.2789
# Epoch 130:
# Training accuracy: 54.24%, loss: 0.1761
# Validaion accuracy: 30.31%, loss: 0.2874
# Epoch 131:
# [MODEL SAVED]
# Training accuracy: 54.07%, loss: 0.1772
# Validaion accuracy: 33.31%, loss: 0.2655
# Epoch 132:
# Training accuracy: 54.63%, loss: 0.1741
# Validaion accuracy: 31.63%, loss: 0.2828
# Epoch 133:
# Training accuracy: 53.64%, loss: 0.1774
# Validaion accuracy: 30.20%, loss: 0.2948
# Epoch 134:
# Training accuracy: 54.61%, loss: 0.1749
# Validaion accuracy: 32.43%, loss: 0.2730
# Epoch 135:
# Training accuracy: 53.32%, loss: 0.1787
# Validaion accuracy: 33.34%, loss: 0.2689
# Epoch 136:
# [MODEL SAVED]
# Training accuracy: 53.67%, loss: 0.1779
# Validaion accuracy: 33.74%, loss: 0.2648
# Epoch 137:
# Training accuracy: 54.73%, loss: 0.1761
# Validaion accuracy: 31.33%, loss: 0.2807
# Epoch 138:
# Training accuracy: 55.73%, loss: 0.1691
# Validaion accuracy: 31.51%, loss: 0.2891
# Epoch 139:
# Training accuracy: 55.80%, loss: 0.1715
# Validaion accuracy: 33.53%, loss: 0.2675
# Epoch 140:
# Training accuracy: 55.14%, loss: 0.1741
# Validaion accuracy: 31.88%, loss: 0.2657
# Epoch 141:
# Training accuracy: 54.42%, loss: 0.1732
# Validaion accuracy: 32.75%, loss: 0.2672
# Epoch 142:
# Training accuracy: 53.68%, loss: 0.1748
# Validaion accuracy: 31.41%, loss: 0.2792
# Epoch 143:
# Training accuracy: 54.33%, loss: 0.1763
# Validaion accuracy: 30.27%, loss: 0.2951
# Epoch 144:
# Training accuracy: 55.09%, loss: 0.1734
# Validaion accuracy: 31.33%, loss: 0.2819
# Epoch 145:
# Training accuracy: 53.59%, loss: 0.1774
# Validaion accuracy: 29.94%, loss: 0.3046
# Epoch 146:
# Training accuracy: 54.81%, loss: 0.1733
# Validaion accuracy: 31.41%, loss: 0.2793
# Epoch 147:
# Training accuracy: 55.25%, loss: 0.1722
# Validaion accuracy: 31.07%, loss: 0.2910
# Epoch 148:
# Training accuracy: 54.46%, loss: 0.1752
# Validaion accuracy: 32.65%, loss: 0.2746
# Epoch 149:
# Training accuracy: 54.83%, loss: 0.1735
# Validaion accuracy: 33.44%, loss: 0.2825
# Epoch 150:
# Training accuracy: 53.94%, loss: 0.1750
# Validaion accuracy: 30.72%, loss: 0.2916
# Epoch 151:
# Training accuracy: 54.02%, loss: 0.1750
# Validaion accuracy: 31.58%, loss: 0.2676
# Epoch 152:
# Training accuracy: 55.45%, loss: 0.1734
# Validaion accuracy: 32.25%, loss: 0.2787
# Epoch 153:
# Training accuracy: 54.95%, loss: 0.1721
# Validaion accuracy: 33.13%, loss: 0.2715
# Epoch 154:
# Training accuracy: 54.70%, loss: 0.1727
# Validaion accuracy: 31.96%, loss: 0.2761
# Epoch 155:
# Training accuracy: 53.41%, loss: 0.1780
# Validaion accuracy: 31.17%, loss: 0.2792
# Epoch 156:
# Training accuracy: 55.83%, loss: 0.1725
# Validaion accuracy: 26.43%, loss: 0.3065
# Epoch 157:
# [MODEL SAVED]
# Training accuracy: 54.41%, loss: 0.1732
# Validaion accuracy: 31.89%, loss: 0.2645
# Epoch 158:
# Training accuracy: 55.09%, loss: 0.1746
# Validaion accuracy: 30.95%, loss: 0.2792
# Epoch 159:
# Training accuracy: 55.90%, loss: 0.1706
# Validaion accuracy: 32.93%, loss: 0.2698
# Epoch 160:
# Training accuracy: 54.90%, loss: 0.1729
# Validaion accuracy: 33.67%, loss: 0.2845
# Epoch 161:
# Training accuracy: 55.21%, loss: 0.1721
# Validaion accuracy: 31.85%, loss: 0.2729
# Epoch 162:
# Training accuracy: 55.68%, loss: 0.1707
# Validaion accuracy: 32.30%, loss: 0.2699
# Epoch 163:
# Training accuracy: 54.86%, loss: 0.1736
# Validaion accuracy: 29.78%, loss: 0.2873
# Epoch 164:
# Training accuracy: 56.14%, loss: 0.1701
# Validaion accuracy: 31.43%, loss: 0.2762
# Epoch 165:
# Training accuracy: 55.24%, loss: 0.1710
# Validaion accuracy: 31.87%, loss: 0.2789
# Epoch 166:
# Training accuracy: 55.04%, loss: 0.1725
# Validaion accuracy: 30.52%, loss: 0.2927
# Epoch 167:
# Training accuracy: 54.92%, loss: 0.1728
# Validaion accuracy: 31.09%, loss: 0.2767
# Epoch 168:
# Training accuracy: 55.32%, loss: 0.1717
# Validaion accuracy: 32.72%, loss: 0.2760
# Epoch 169:
# Training accuracy: 55.69%, loss: 0.1706
# Validaion accuracy: 28.43%, loss: 0.2874
# Epoch 170:
# Training accuracy: 56.55%, loss: 0.1689
# Validaion accuracy: 31.36%, loss: 0.2736
# Epoch 171:
# Training accuracy: 55.07%, loss: 0.1743
# Validaion accuracy: 32.92%, loss: 0.2656
# Epoch 172:
# Training accuracy: 54.91%, loss: 0.1733
# Validaion accuracy: 33.43%, loss: 0.2723
# Epoch 173:
# Training accuracy: 55.19%, loss: 0.1722
# Validaion accuracy: 30.92%, loss: 0.2701
# Epoch 174:
# Training accuracy: 55.16%, loss: 0.1715
# Validaion accuracy: 31.96%, loss: 0.2776
# Epoch 175:
# Training accuracy: 55.91%, loss: 0.1699
# Validaion accuracy: 32.68%, loss: 0.2667
# Epoch 176:
# Training accuracy: 55.36%, loss: 0.1709
# Validaion accuracy: 31.07%, loss: 0.2692
# Epoch 177:
# Training accuracy: 54.33%, loss: 0.1746
# Validaion accuracy: 31.89%, loss: 0.2681
# Epoch 178:
# [MODEL SAVED]
# Training accuracy: 56.02%, loss: 0.1702
# Validaion accuracy: 35.17%, loss: 0.2523
# Epoch 179:
# Training accuracy: 56.31%, loss: 0.1686
# Validaion accuracy: 30.80%, loss: 0.2931
# Epoch 180:
# Training accuracy: 55.97%, loss: 0.1705
# Validaion accuracy: 33.45%, loss: 0.2664
# Epoch 181:
# Training accuracy: 54.50%, loss: 0.1714
# Validaion accuracy: 33.65%, loss: 0.2603
# Epoch 182:
# Training accuracy: 55.26%, loss: 0.1721
# Validaion accuracy: 31.02%, loss: 0.2769
# Epoch 183:
# Training accuracy: 54.85%, loss: 0.1725
# Validaion accuracy: 32.82%, loss: 0.2671
# Epoch 184:
# Training accuracy: 54.16%, loss: 0.1734
# Validaion accuracy: 32.85%, loss: 0.2769
# Epoch 185:
# Training accuracy: 55.41%, loss: 0.1719
# Validaion accuracy: 31.21%, loss: 0.2765
# Epoch 186:
# Training accuracy: 54.61%, loss: 0.1716
# Validaion accuracy: 31.54%, loss: 0.2708
# Epoch 187:
# Training accuracy: 55.18%, loss: 0.1709
# Validaion accuracy: 31.17%, loss: 0.2843
# Epoch 188:
# Training accuracy: 55.42%, loss: 0.1712
# Validaion accuracy: 32.25%, loss: 0.2672
# Epoch 189:
# Training accuracy: 55.60%, loss: 0.1710
# Validaion accuracy: 34.02%, loss: 0.2766
# Epoch 190:
# Training accuracy: 55.07%, loss: 0.1727
# Validaion accuracy: 31.96%, loss: 0.2776
# Epoch 191:
# Training accuracy: 56.74%, loss: 0.1686
# Validaion accuracy: 31.48%, loss: 0.2839
# Epoch 192:
# Training accuracy: 55.86%, loss: 0.1693
# Validaion accuracy: 33.64%, loss: 0.2859
# Epoch 193:
# Training accuracy: 56.40%, loss: 0.1682
# Validaion accuracy: 35.35%, loss: 0.2781
# Epoch 194:
# Training accuracy: 56.50%, loss: 0.1676
# Validaion accuracy: 33.93%, loss: 0.2714
# Epoch 195:
# Training accuracy: 54.99%, loss: 0.1728
# Validaion accuracy: 33.52%, loss: 0.2776
# Epoch 196:
# Training accuracy: 55.81%, loss: 0.1692
# Validaion accuracy: 32.40%, loss: 0.2823
# Epoch 197:
# Training accuracy: 55.33%, loss: 0.1720
# Validaion accuracy: 32.62%, loss: 0.2832
# Epoch 198:
# Training accuracy: 56.42%, loss: 0.1708
# Validaion accuracy: 32.56%, loss: 0.2766
# Epoch 199:
# Training accuracy: 54.90%, loss: 0.1724
# Validaion accuracy: 33.41%, loss: 0.2632
# Epoch 200:
# Training accuracy: 56.43%, loss: 0.1683
# Validaion accuracy: 33.66%, loss: 0.2671

# %% [markdown]
# Test the model with test_dataset. <font color='red'>The test accuracy must reach at least 28%.</font>

# %%
test_dataloader = Dataloader(test_dataset)
model.load_model(MODEL_PATH)
model.test(test_dataloader)
# Out:
# Got 3449 correct prediction in 10000 test data, accuracy: 34.49%

# %% [markdown]
# # Try Deeper NN

# %%
class Softmax_CrossEntropy_overflow(object):
  def __init__(self):
    pass
  def forward(self, y, net_out):
    N, F = net_out.shape
    net_out_max = torch.max(net_out, dim=1, keepdim=True)[0]
    net_out_exp = torch.exp(net_out - net_out_max)
    # net_out_exp = torch.exp(net_out)
    prob = net_out_exp / torch.sum(net_out_exp, dim=1, keepdim=True)
    self.cache = (y, prob)
    pred_y = prob.argmax(dim=1)
    y_one_hot = torch.zeros_like(net_out)
    y_one_hot[np.arange(N), y] = 1
    loss = torch.zeros(1)
    loss = -torch.sum(y_one_hot * torch.log(prob)) / N
    return pred_y, loss

  def backward(self):
    y, prob = self.cache
    N, F = prob.shape
    y_one_hot = torch.zeros_like(prob)
    y_one_hot[np.arange(N), y] = 1
    grad = (prob - y_one_hot) / N
    return grad

# %%
layer = Softmax_CrossEntropy_overflow()
SCE_Tests(layer)
# Out:
# Results of softmax and cross entropy forward and backward tests: All passed.

# %%
class Deeper_Classifier(object):
  def __init__(self, dim_in, dim_hidden1, dim_hidden2, dim_out, device='cpu'):
    self.dv = device
    np.random.seed(0)
    self.params = {
             'w1': torch.from_numpy(np.random.randn(dim_in, dim_hidden1)*0.8).to(self.dv),
             'b1': torch.zeros(dim_hidden1).to(self.dv),
             'w2': torch.from_numpy(np.random.randn(dim_hidden1, dim_hidden2)*0.8).to(self.dv),
             'b2': torch.zeros(dim_hidden2).to(self.dv),
             'w3': torch.from_numpy(np.random.randn(dim_hidden2, dim_out)*0.8).to(self.dv),
             'b3': torch.zeros(dim_out).to(self.dv)
             }
    layer1 = FullyConnectedLayer()
    activation1 = ReLU()
    layer2 = FullyConnectedLayer()
    activation2 = ReLU()
    layer3 = FullyConnectedLayer()
    self.net = [layer1, activation1, layer2, activation2, layer3]
    self.loss_func = Softmax_CrossEntropy_overflow()
  def save_model(self, path):
    torch.save(self.params, path)
  def load_model(self, path):
    checkpoint = torch.load(path, map_location=self.dv)
    self.params = checkpoint
  def training(self, train_dataloader, valid_dataloader, epochs=200, learning_rate=1e-3, learning_rate_decay=0.95, verbose=1):
    print(f'Training with batch_size={train_dataloader[0][0].shape[0]}, hidden_dim1={self.params["w1"].shape[1]}, hidden_dim2={self.params["w2"].shape[1]}, learning_rate={learning_rate}, learning_rate_decay={learning_rate_decay}')
    train_loss_log = []
    train_acc_log = []
    valid_loss_log = []
    valid_acc_log = []
    best_val_loss = None
    for epoch in range(epochs):
      if verbose > 0 and (epoch+1) % verbose == 0:
        print(f'Epoch {epoch+1}:')
      single_epoch_log = ''
      train_loss = 0.0
      train_corr = 0.0; train_eval = 0.0
      for batch_idx in range(len(train_dataloader)):
        ### Model Input and Loss Calculation ###
        batch_data = train_dataloader[batch_idx]
        batch_img, batch_label = batch_data
        layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
        layer1_out = self.net[1].forward(layer1_out)
        layer2_out = self.net[2].forward(layer1_out.to(self.dv), self.params['w2'], self.params['b2'])
        layer2_out = self.net[3].forward(layer2_out)
        layer3_out = self.net[4].forward(layer2_out, self.params['w3'], self.params['b3'])
        pred_y, loss = self.loss_func.forward(batch_label, layer3_out)
        train_loss += loss.cpu().numpy()
        train_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
        train_eval += batch_img.shape[0]
        ### Backpropagation and Optimization ###

        # self.net = [layer1, activation1, layer2, activation2, layer3]
        
        params_grad = {}
        dloss_dout3 = self.loss_func.backward()
        dout3_dw3, dout3_db3 = self.net[4].backward(dloss_dout3)
        params_grad['w3'] = dout3_dw3; params_grad['b3'] = dout3_db3

        dout3_dout2 = self.net[3].backward(dloss_dout3.mm(self.params['w3'].T))
        dout2_dw2, dout2_db2 = self.net[2].backward(dout3_dout2)
        params_grad['w2'] = dout2_dw2; params_grad['b2'] = dout2_db2

        dout2_dout1 = self.net[1].backward(dout3_dout2.mm(self.params['w2'].T))
        dout1_dw1, dout1_db1 = self.net[0].backward(dout2_dout1)
        params_grad['w1'] = dout1_dw1; params_grad['b1'] = dout1_db1

        self.params['w1'] -= learning_rate * params_grad['w1']
        self.params['b1'] -= learning_rate * params_grad['b1']
        self.params['w2'] -= learning_rate * params_grad['w2']
        self.params['b2'] -= learning_rate * params_grad['b2']
        self.params['w3'] -= learning_rate * params_grad['w3']
        self.params['b3'] -= learning_rate * params_grad['b3']

        
      train_loss_log.append(train_loss/train_eval)
      train_acc_log.append(100*train_corr/train_eval)
      single_epoch_log += f'Training accuracy: {format(train_acc_log[-1], ".2f")}%, loss: {format(train_loss_log[-1], ".4f")}\n'
      train_dataloader.shuffle()

      valid_loss = 0.0
      valid_corr = 0.0; valid_eval = 0.0
      for batch_idx in range(len(valid_dataloader)):
        ### Model Input and Loss Calculation ###
        batch_data = valid_dataloader[batch_idx]
        batch_img, batch_label = batch_data
        layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
        layer1_out = self.net[1].forward(layer1_out)
        layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
        layer2_out = self.net[3].forward(layer2_out)
        layer3_out = self.net[4].forward(layer2_out, self.params['w3'], self.params['b3'])
        pred_y, loss = self.loss_func.forward(batch_label, layer3_out)

        valid_loss += loss.cpu().numpy()
        valid_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
        valid_eval += batch_img.shape[0]
      valid_loss_log.append(valid_loss/valid_eval)
      valid_acc_log.append(100*valid_corr/valid_eval)
      single_epoch_log += f'Validaion accuracy: {format(valid_acc_log[-1], ".2f")}%, loss: {format(valid_loss_log[-1], ".4f")}'
      if best_val_loss is None or valid_loss < best_val_loss:
        best_val_loss = valid_loss
        self.save_model(MODEL_PATH)
        if verbose == 1:
          single_epoch_log = '[MODEL SAVED]\n' + single_epoch_log
      if verbose > 0 and (epoch+1) % verbose == 0:
        print(single_epoch_log)
      learning_rate *= learning_rate_decay # update learning_rate every epoch
    return train_loss_log,train_acc_log,valid_loss_log,valid_acc_log
  def test(self, test_dataloader):
    total_corr = 0; total_eval = 0
    for batch_idx in range(len(test_dataloader)):
      ### Model Input ###
      batch_data = test_dataloader[batch_idx]
      batch_img, batch_label = batch_data
      layer1_out = self.net[0].forward(torch.from_numpy(batch_img).to(self.dv), self.params['w1'], self.params['b1'])
      layer1_out = self.net[1].forward(layer1_out)
      layer2_out = self.net[2].forward(layer1_out, self.params['w2'], self.params['b2'])
      layer2_out = self.net[3].forward(layer2_out)
      layer3_out = self.net[4].forward(layer2_out, self.params['w3'], self.params['b3'])
      pred_y, _ = self.loss_func.forward(batch_label, layer3_out)
      total_corr += torch.count_nonzero(pred_y == torch.from_numpy(batch_label).to(self.dv)).cpu().numpy()
      total_eval += batch_img.shape[0]
    print(f'Got {total_corr} correct prediction in {total_eval} test data, accuracy: {format((total_corr*1.0/total_eval)*100, ".2f")}%')

# %%
# Please set your hyperparameters here
BATCH_SIZE = 128
LR = 1e-2
LR_DECAY = 1
HIDEEN_DIM1 = 1024
HIDEEN_DIM2 = 128

# Configurations
IN_DIM = np.prod(images[0].shape)
OUT_DIM = len(classes)

# %%
train_dataloader = Dataloader(train_dataset, batch_size=BATCH_SIZE)
valid_dataloader = Dataloader(valid_dataset, batch_size=BATCH_SIZE)
model = Deeper_Classifier(IN_DIM, HIDEEN_DIM1, HIDEEN_DIM2, OUT_DIM, device=DEVICE)
train_loss, train_acc, valid_loss, valid_acc = model.training(train_dataloader, valid_dataloader, learning_rate=LR, learning_rate_decay=LR_DECAY)
plot_result(train_loss, train_acc, valid_loss, valid_acc)
# Out:
# Training with batch_size=128, hidden_dim1=1024, hidden_dim2=128, learning_rate=0.01, learning_rate_decay=1
# Epoch 1:
# [MODEL SAVED]
# Training accuracy: 22.44%, loss: nan
# Validaion accuracy: 13.86%, loss: nan
# Epoch 2:
# Training accuracy: 28.11%, loss: nan
# Validaion accuracy: 18.39%, loss: nan
# Epoch 3:
# Training accuracy: 29.27%, loss: nan
# Validaion accuracy: 21.95%, loss: nan
# Epoch 4:
# Training accuracy: 33.28%, loss: nan
# Validaion accuracy: 20.72%, loss: nan
# Epoch 5:
# Training accuracy: 32.28%, loss: nan
# Validaion accuracy: 25.57%, loss: nan
# Epoch 6:
# Training accuracy: 31.31%, loss: nan
# Validaion accuracy: 20.99%, loss: nan
# Epoch 7:
# Training accuracy: 30.50%, loss: nan
# Validaion accuracy: 21.19%, loss: nan
# Epoch 8:
# Training accuracy: 30.56%, loss: nan
# Validaion accuracy: 22.16%, loss: nan
# Epoch 9:
# Training accuracy: 32.26%, loss: nan
# Validaion accuracy: 24.12%, loss: nan
# Epoch 10:
# Training accuracy: 31.24%, loss: nan
# Validaion accuracy: 25.13%, loss: nan
# Epoch 11:
# Training accuracy: 30.25%, loss: nan
# Validaion accuracy: 23.25%, loss: nan
# Epoch 12:
# Training accuracy: 33.61%, loss: nan
# Validaion accuracy: 24.53%, loss: nan
# Epoch 13:
# Training accuracy: 34.25%, loss: nan
# Validaion accuracy: 23.36%, loss: nan
# Epoch 14:
# Training accuracy: 32.57%, loss: nan
# Validaion accuracy: 23.78%, loss: nan
# Epoch 15:
# Training accuracy: 31.61%, loss: nan
# Validaion accuracy: 21.01%, loss: nan
# Epoch 16:
# Training accuracy: 30.72%, loss: nan
# Validaion accuracy: 21.48%, loss: nan
# Epoch 17:
# Training accuracy: 29.30%, loss: nan
# Validaion accuracy: 21.73%, loss: nan
# Epoch 18:
# Training accuracy: 27.62%, loss: nan
# Validaion accuracy: 23.37%, loss: nan
# Epoch 19:
# Training accuracy: 32.56%, loss: nan
# Validaion accuracy: 26.80%, loss: nan
# Epoch 20:
# Training accuracy: 30.06%, loss: nan
# Validaion accuracy: 26.92%, loss: nan
# Epoch 21:
# Training accuracy: 32.29%, loss: nan
# Validaion accuracy: 23.83%, loss: nan
# Epoch 22:
# Training accuracy: 32.71%, loss: nan
# Validaion accuracy: 23.13%, loss: nan
# Epoch 23:
# Training accuracy: 26.99%, loss: nan
# Validaion accuracy: 24.26%, loss: nan
# Epoch 24:
# Training accuracy: 29.02%, loss: nan
# Validaion accuracy: 22.99%, loss: nan
# Epoch 25:
# Training accuracy: 33.41%, loss: nan
# Validaion accuracy: 21.67%, loss: nan
# Epoch 26:
# Training accuracy: 33.27%, loss: nan
# Validaion accuracy: 25.74%, loss: nan
# Epoch 27:
# Training accuracy: 30.23%, loss: nan
# Validaion accuracy: 25.96%, loss: nan
# Epoch 28:
# Training accuracy: 31.01%, loss: nan
# Validaion accuracy: 22.11%, loss: nan
# Epoch 29:
# Training accuracy: 32.13%, loss: nan
# Validaion accuracy: 25.01%, loss: nan
# Epoch 30:
# Training accuracy: 31.31%, loss: nan
# Validaion accuracy: 23.39%, loss: 0.4557
# Epoch 31:
# Training accuracy: 26.89%, loss: nan
# Validaion accuracy: 19.66%, loss: nan
# Epoch 32:
# Training accuracy: 27.30%, loss: nan
# Validaion accuracy: 21.24%, loss: nan
# Epoch 33:
# Training accuracy: 30.56%, loss: 0.3291
# Validaion accuracy: 21.31%, loss: 0.4900
# Epoch 34:
# Training accuracy: 31.01%, loss: nan
# Validaion accuracy: 19.73%, loss: nan
# Epoch 35:
# Training accuracy: 29.69%, loss: nan
# Validaion accuracy: 22.22%, loss: nan
# Epoch 36:
# Training accuracy: 34.10%, loss: nan
# Validaion accuracy: 19.18%, loss: nan
# Epoch 37:
# Training accuracy: 28.97%, loss: 0.2639
# Validaion accuracy: 18.88%, loss: nan
# Epoch 38:
# Training accuracy: 30.96%, loss: nan
# Validaion accuracy: 18.79%, loss: nan
# Epoch 39:
# Training accuracy: 28.09%, loss: nan
# Validaion accuracy: 19.99%, loss: nan
# Epoch 40:
# Training accuracy: 30.32%, loss: 0.2198
# Validaion accuracy: 25.87%, loss: nan
# Epoch 41:
# Training accuracy: 32.66%, loss: nan
# Validaion accuracy: 17.04%, loss: 0.2810
# Epoch 42:
# Training accuracy: 34.60%, loss: 0.1722
# Validaion accuracy: 18.66%, loss: 0.2563
# Epoch 43:
# Training accuracy: 39.00%, loss: nan
# Validaion accuracy: 22.74%, loss: 0.2334
# Epoch 44:
# Training accuracy: 30.93%, loss: 0.1525
# Validaion accuracy: 20.71%, loss: nan
# Epoch 45:
# Training accuracy: 36.65%, loss: 0.1176
# Validaion accuracy: 16.79%, loss: 0.2154
# Epoch 46:
# Training accuracy: 33.24%, loss: 0.1261
# Validaion accuracy: 17.60%, loss: 0.2263
# Epoch 47:
# Training accuracy: 37.46%, loss: 0.0978
# Validaion accuracy: 21.10%, loss: 0.1880
# Epoch 48:
# Training accuracy: 37.14%, loss: 0.0941
# Validaion accuracy: 19.78%, loss: 0.1782
# Epoch 49:
# Training accuracy: 37.12%, loss: nan
# Validaion accuracy: 19.46%, loss: 0.1480
# Epoch 50:
# Training accuracy: 34.44%, loss: nan
# Validaion accuracy: 18.30%, loss: 0.1719
# Epoch 51:
# Training accuracy: 37.66%, loss: 0.1035
# Validaion accuracy: 17.18%, loss: 0.1614
# Epoch 52:
# Training accuracy: 35.11%, loss: 0.0972
# Validaion accuracy: 19.27%, loss: 0.1637
# Epoch 53:
# Training accuracy: 38.17%, loss: 0.0874
# Validaion accuracy: 18.69%, loss: 0.1512
# Epoch 54:
# Training accuracy: 37.78%, loss: 0.0702
# Validaion accuracy: 18.91%, loss: 0.1447
# Epoch 55:
# Training accuracy: 38.06%, loss: inf
# Validaion accuracy: 20.06%, loss: 0.1269
# Epoch 56:
# Training accuracy: 45.09%, loss: 0.0603
# Validaion accuracy: 19.16%, loss: 0.1351
# Epoch 57:
# Training accuracy: 39.44%, loss: 0.0547
# Validaion accuracy: 20.74%, loss: 0.1298
# Epoch 58:
# Training accuracy: 42.14%, loss: 0.0453
# Validaion accuracy: 21.50%, loss: 0.1116
# Epoch 59:
# Training accuracy: 39.62%, loss: nan
# Validaion accuracy: 21.15%, loss: 0.1178
# Epoch 60:
# Training accuracy: 42.99%, loss: 0.0474
# Validaion accuracy: 21.30%, loss: 0.1007
# Epoch 61:
# Training accuracy: 39.80%, loss: 0.0528
# Validaion accuracy: 20.20%, loss: 0.1026
# Epoch 62:
# Training accuracy: 44.58%, loss: 0.0362
# Validaion accuracy: 15.30%, loss: 0.1011
# Epoch 63:
# Training accuracy: 41.99%, loss: 0.0359
# Validaion accuracy: 16.30%, loss: 0.0925
# Epoch 64:
# Training accuracy: 43.33%, loss: 0.0555
# Validaion accuracy: 13.58%, loss: 0.1070
# Epoch 65:
# Training accuracy: 40.96%, loss: 0.0444
# Validaion accuracy: 19.02%, loss: 0.0935
# Epoch 66:
# Training accuracy: 47.69%, loss: 0.0450
# Validaion accuracy: 15.12%, loss: 0.1088
# Epoch 67:
# Training accuracy: 42.63%, loss: nan
# Validaion accuracy: 18.45%, loss: 0.0855
# Epoch 68:
# Training accuracy: 41.77%, loss: 0.0414
# Validaion accuracy: 15.04%, loss: 0.0968
# Epoch 69:
# Training accuracy: 42.77%, loss: 0.0399
# Validaion accuracy: 22.00%, loss: 0.0759
# Epoch 70:
# Training accuracy: 43.36%, loss: nan
# Validaion accuracy: 15.82%, loss: 0.0945
# Epoch 71:
# Training accuracy: 42.20%, loss: nan
# Validaion accuracy: 23.12%, loss: 0.0806
# Epoch 72:
# Training accuracy: 45.20%, loss: 0.0354
# Validaion accuracy: 15.67%, loss: 0.0814
# Epoch 73:
# Training accuracy: 44.76%, loss: 0.0282
# Validaion accuracy: 14.10%, loss: 0.0771
# Epoch 74:
# Training accuracy: 46.70%, loss: 0.0234
# Validaion accuracy: 18.06%, loss: 0.0758
# Epoch 75:
# Training accuracy: 45.90%, loss: 0.0325
# Validaion accuracy: 17.72%, loss: 0.0739
# Epoch 76:
# Training accuracy: 46.56%, loss: 0.0240
# Validaion accuracy: 13.69%, loss: 0.0824
# Epoch 77:
# Training accuracy: 45.96%, loss: nan
# Validaion accuracy: 12.16%, loss: 0.0732
# Epoch 78:
# Training accuracy: 41.09%, loss: 0.0418
# Validaion accuracy: 17.92%, loss: 0.0673
# Epoch 79:
# Training accuracy: 45.43%, loss: 0.0246
# Validaion accuracy: 20.67%, loss: 0.0683
# Epoch 80:
# Training accuracy: 42.81%, loss: 0.0262
# Validaion accuracy: 22.79%, loss: 0.0678
# Epoch 81:
# Training accuracy: 44.38%, loss: 0.0249
# Validaion accuracy: 16.18%, loss: 0.0661
# Epoch 82:
# Training accuracy: 41.29%, loss: 0.0295
# Validaion accuracy: 15.36%, loss: 0.0726
# Epoch 83:
# Training accuracy: 48.70%, loss: 0.0245
# Validaion accuracy: 19.97%, loss: 0.0660
# Epoch 84:
# Training accuracy: 48.27%, loss: 0.0232
# Validaion accuracy: 19.85%, loss: 0.0627
# Epoch 85:
# Training accuracy: 47.96%, loss: 0.0324
# Validaion accuracy: 14.83%, loss: 0.0639
# Epoch 86:
# Training accuracy: 48.53%, loss: 0.0282
# Validaion accuracy: 18.19%, loss: 0.0633
# Epoch 87:
# Training accuracy: 53.77%, loss: 0.0221
# Validaion accuracy: 21.74%, loss: 0.0628
# Epoch 88:
# Training accuracy: 46.93%, loss: 0.0306
# Validaion accuracy: 15.24%, loss: 0.0694
# Epoch 89:
# Training accuracy: 47.89%, loss: 0.0179
# Validaion accuracy: 18.50%, loss: 0.0627
# Epoch 90:
# Training accuracy: 47.13%, loss: 0.0211
# Validaion accuracy: 25.00%, loss: 0.0511
# Epoch 91:
# Training accuracy: 47.59%, loss: 0.0237
# Validaion accuracy: 19.44%, loss: 0.0578
# Epoch 92:
# Training accuracy: 49.22%, loss: 0.0288
# Validaion accuracy: 18.82%, loss: 0.0625
# Epoch 93:
# Training accuracy: 51.23%, loss: 0.0230
# Validaion accuracy: 23.34%, loss: 0.0492
# Epoch 94:
# Training accuracy: 50.68%, loss: 0.0249
# Validaion accuracy: 15.85%, loss: 0.0609
# Epoch 95:
# Training accuracy: 48.38%, loss: 0.0286
# Validaion accuracy: 19.09%, loss: 0.0588
# Epoch 96:
# Training accuracy: 49.09%, loss: 0.0214
# Validaion accuracy: 18.44%, loss: 0.0585
# Epoch 97:
# Training accuracy: 47.66%, loss: 0.0371
# Validaion accuracy: 21.70%, loss: 0.0540
# Epoch 98:
# Training accuracy: 51.02%, loss: 0.0155
# Validaion accuracy: 18.00%, loss: 0.0511
# Epoch 99:
# Training accuracy: 50.70%, loss: 0.0158
# Validaion accuracy: 17.75%, loss: 0.0564
# Epoch 100:
# Training accuracy: 52.89%, loss: 0.0201
# Validaion accuracy: 13.15%, loss: 0.0567
# Epoch 101:
# Training accuracy: 50.12%, loss: 0.0238
# Validaion accuracy: 18.99%, loss: 0.0529
# Epoch 102:
# Training accuracy: 47.59%, loss: 0.0217
# Validaion accuracy: 17.45%, loss: 0.0548
# Epoch 103:
# Training accuracy: 46.72%, loss: 0.0184
# Validaion accuracy: 22.48%, loss: 0.0530
# Epoch 104:
# Training accuracy: 46.89%, loss: 0.0295
# Validaion accuracy: 23.51%, loss: 0.0506
# Epoch 105:
# Training accuracy: 50.44%, loss: 0.0173
# Validaion accuracy: 14.58%, loss: 0.0545
# Epoch 106:
# Training accuracy: 49.70%, loss: 0.0206
# Validaion accuracy: 15.70%, loss: 0.0543
# Epoch 107:
# Training accuracy: 49.05%, loss: 0.0184
# Validaion accuracy: 17.01%, loss: 0.0520
# Epoch 108:
# Training accuracy: 48.13%, loss: 0.0167
# Validaion accuracy: 19.03%, loss: 0.0524
# Epoch 109:
# Training accuracy: 51.46%, loss: 0.0124
# Validaion accuracy: 14.18%, loss: 0.0541
# Epoch 110:
# Training accuracy: 48.91%, loss: 0.0209
# Validaion accuracy: 20.43%, loss: 0.0515
# Epoch 111:
# Training accuracy: 54.96%, loss: 0.0194
# Validaion accuracy: 22.52%, loss: 0.0501
# Epoch 112:
# Training accuracy: 49.27%, loss: 0.0241
# Validaion accuracy: 18.64%, loss: 0.0511
# Epoch 113:
# Training accuracy: 50.04%, loss: 0.0203
# Validaion accuracy: 18.45%, loss: 0.0499
# Epoch 114:
# Training accuracy: 54.21%, loss: 0.0127
# Validaion accuracy: 16.23%, loss: 0.0498
# Epoch 115:
# Training accuracy: 55.87%, loss: 0.0195
# Validaion accuracy: 17.59%, loss: 0.0489
# Epoch 116:
# Training accuracy: 52.56%, loss: 0.0139
# Validaion accuracy: 19.60%, loss: 0.0476
# Epoch 117:
# Training accuracy: 56.62%, loss: nan
# Validaion accuracy: 17.59%, loss: 0.0480
# Epoch 118:
# Training accuracy: 51.81%, loss: 0.0205
# Validaion accuracy: 21.91%, loss: 0.0490
# Epoch 119:
# Training accuracy: 48.07%, loss: 0.0155
# Validaion accuracy: 14.86%, loss: 0.0509
# Epoch 120:
# Training accuracy: 49.02%, loss: nan
# Validaion accuracy: 21.69%, loss: 0.0456
# Epoch 121:
# Training accuracy: 52.37%, loss: 0.0148
# Validaion accuracy: 14.50%, loss: 0.0499
# Epoch 122:
# Training accuracy: 52.75%, loss: 0.0148
# Validaion accuracy: 18.23%, loss: 0.0457
# Epoch 123:
# Training accuracy: 56.76%, loss: 0.0164
# Validaion accuracy: 14.39%, loss: 0.0495
# Epoch 124:
# Training accuracy: 52.48%, loss: 0.0160
# Validaion accuracy: 21.75%, loss: 0.0467
# Epoch 125:
# Training accuracy: 58.94%, loss: 0.0109
# Validaion accuracy: 23.31%, loss: 0.0416
# Epoch 126:
# Training accuracy: 49.20%, loss: 0.0202
# Validaion accuracy: 25.12%, loss: 0.0431
# Epoch 127:
# Training accuracy: 58.97%, loss: 0.0129
# Validaion accuracy: 15.66%, loss: 0.0443
# Epoch 128:
# Training accuracy: 49.88%, loss: 0.0153
# Validaion accuracy: 19.26%, loss: 0.0421
# Epoch 129:
# Training accuracy: 58.18%, loss: 0.0110
# Validaion accuracy: 21.57%, loss: 0.0454
# Epoch 130:
# Training accuracy: 53.66%, loss: 0.0227
# Validaion accuracy: 15.96%, loss: 0.0459
# Epoch 131:
# Training accuracy: 53.31%, loss: 0.0181
# Validaion accuracy: 18.37%, loss: 0.0482
# Epoch 132:
# Training accuracy: 52.38%, loss: 0.0181
# Validaion accuracy: 18.10%, loss: 0.0446
# Epoch 133:
# Training accuracy: 49.08%, loss: 0.0261
# Validaion accuracy: 19.00%, loss: 0.0415
# Epoch 134:
# Training accuracy: 51.97%, loss: 0.0152
# Validaion accuracy: 16.61%, loss: 0.0421
# Epoch 135:
# Training accuracy: 57.55%, loss: 0.0132
# Validaion accuracy: 19.63%, loss: 0.0459
# Epoch 136:
# Training accuracy: 60.95%, loss: 0.0216
# Validaion accuracy: 20.61%, loss: 0.0479
# Epoch 137:
# Training accuracy: 59.67%, loss: 0.0124
# Validaion accuracy: 17.24%, loss: 0.0467
# Epoch 138:
# Training accuracy: 53.30%, loss: 0.0179
# Validaion accuracy: 17.63%, loss: 0.0507
# Epoch 139:
# Training accuracy: 55.00%, loss: 0.0158
# Validaion accuracy: 14.00%, loss: 0.0459
# Epoch 140:
# Training accuracy: 57.21%, loss: 0.0112
# Validaion accuracy: 20.36%, loss: 0.0436
# Epoch 141:
# Training accuracy: 57.41%, loss: 0.0115
# Validaion accuracy: 19.74%, loss: 0.0425
# Epoch 142:
# Training accuracy: 54.84%, loss: 0.0200
# Validaion accuracy: 21.54%, loss: 0.0411
# Epoch 143:
# Training accuracy: 53.00%, loss: 0.0136
# Validaion accuracy: 21.16%, loss: 0.0423
# Epoch 144:
# Training accuracy: 54.66%, loss: 0.0126
# Validaion accuracy: 19.47%, loss: 0.0430
# Epoch 145:
# Training accuracy: 55.13%, loss: 0.0122
# Validaion accuracy: 18.30%, loss: 0.0415
# Epoch 146:
# Training accuracy: 56.34%, loss: 0.0185
# Validaion accuracy: 12.56%, loss: 0.0468
# Epoch 147:
# Training accuracy: 55.25%, loss: 0.0137
# Validaion accuracy: 15.31%, loss: 0.0444
# Epoch 148:
# Training accuracy: 58.88%, loss: 0.0162
# Validaion accuracy: 19.54%, loss: 0.0442
# Epoch 149:
# Training accuracy: 48.58%, loss: 0.0194
# Validaion accuracy: 25.66%, loss: 0.0416
# Epoch 150:
# Training accuracy: 55.53%, loss: 0.0191
# Validaion accuracy: 22.63%, loss: 0.0425
# Epoch 151:
# Training accuracy: 56.62%, loss: 0.0151
# Validaion accuracy: 17.26%, loss: 0.0419
# Epoch 152:
# Training accuracy: 58.50%, loss: 0.0110
# Validaion accuracy: 15.53%, loss: 0.0458
# Epoch 153:
# Training accuracy: 55.97%, loss: 0.0173
# Validaion accuracy: 14.39%, loss: 0.0427
# Epoch 154:
# Training accuracy: 55.97%, loss: 0.0273
# Validaion accuracy: 18.86%, loss: 0.0465
# Epoch 155:
# Training accuracy: 55.01%, loss: 0.0144
# Validaion accuracy: 20.38%, loss: 0.0486
# Epoch 156:
# Training accuracy: 57.95%, loss: 0.0147
# Validaion accuracy: 18.54%, loss: 0.0454
# Epoch 157:
# Training accuracy: 54.41%, loss: 0.0186
# Validaion accuracy: 18.33%, loss: 0.0448
# Epoch 158:
# Training accuracy: 56.94%, loss: 0.0174
# Validaion accuracy: 22.09%, loss: 0.0438
# Epoch 159:
# Training accuracy: 56.19%, loss: 0.0199
# Validaion accuracy: 14.68%, loss: 0.0468
# Epoch 160:
# Training accuracy: 58.06%, loss: 0.0119
# Validaion accuracy: 16.94%, loss: 0.0424
# Epoch 161:
# Training accuracy: 58.82%, loss: 0.0114
# Validaion accuracy: 20.19%, loss: 0.0421
# Epoch 162:
# Training accuracy: 57.20%, loss: 0.0134
# Validaion accuracy: 12.54%, loss: 0.0425
# Epoch 163:
# Training accuracy: 53.90%, loss: 0.0138
# Validaion accuracy: 21.81%, loss: 0.0409
# Epoch 164:
# Training accuracy: 58.88%, loss: 0.0121
# Validaion accuracy: 16.82%, loss: 0.0459
# Epoch 165:
# Training accuracy: 58.77%, loss: 0.0110
# Validaion accuracy: 20.88%, loss: 0.0408
# Epoch 166:
# Training accuracy: 55.52%, loss: 0.0127
# Validaion accuracy: 20.65%, loss: 0.0444
# Epoch 167:
# Training accuracy: 59.89%, loss: 0.0163
# Validaion accuracy: 15.97%, loss: 0.0450
# Epoch 168:
# Training accuracy: 58.17%, loss: 0.0116
# Validaion accuracy: 16.37%, loss: 0.0395
# Epoch 169:
# Training accuracy: 60.36%, loss: 0.0108
# Validaion accuracy: 19.31%, loss: 0.0402
# Epoch 170:
# Training accuracy: 55.27%, loss: 0.0117
# Validaion accuracy: 22.25%, loss: 0.0428
# Epoch 171:
# Training accuracy: 60.04%, loss: 0.0136
# Validaion accuracy: 16.35%, loss: 0.0463
# Epoch 172:
# Training accuracy: 57.79%, loss: nan
# Validaion accuracy: 13.34%, loss: 0.0510
# Epoch 173:
# Training accuracy: 55.30%, loss: 0.0177
# Validaion accuracy: 12.97%, loss: 0.0469
# Epoch 174:
# Training accuracy: 52.80%, loss: 0.0175
# Validaion accuracy: 17.06%, loss: 0.0440
# Epoch 175:
# Training accuracy: 55.86%, loss: 0.0144
# Validaion accuracy: 13.97%, loss: 0.0406
# Epoch 176:
# Training accuracy: 60.05%, loss: 0.0106
# Validaion accuracy: 21.17%, loss: 0.0456
# Epoch 177:
# Training accuracy: 56.80%, loss: 0.0178
# Validaion accuracy: 13.25%, loss: 0.0419
# Epoch 178:
# Training accuracy: 59.70%, loss: 0.0119
# Validaion accuracy: 22.55%, loss: 0.0385
# Epoch 179:
# Training accuracy: 56.90%, loss: 0.0117
# Validaion accuracy: 16.98%, loss: 0.0398
# Epoch 180:
# Training accuracy: 58.44%, loss: 0.0140
# Validaion accuracy: 21.91%, loss: 0.0419
# Epoch 181:
# Training accuracy: 52.65%, loss: 0.0169
# Validaion accuracy: 23.09%, loss: 0.0423
# Epoch 182:
# Training accuracy: 53.53%, loss: 0.0124
# Validaion accuracy: 19.50%, loss: 0.0400
# Epoch 183:
# Training accuracy: 52.31%, loss: 0.0133
# Validaion accuracy: 18.29%, loss: 0.0385
# Epoch 184:
# Training accuracy: 62.21%, loss: 0.0177
# Validaion accuracy: 20.93%, loss: 0.0419
# Epoch 185:
# Training accuracy: 60.45%, loss: 0.0154
# Validaion accuracy: 14.79%, loss: 0.0430
# Epoch 186:
# Training accuracy: 62.19%, loss: 0.0106
# Validaion accuracy: 22.77%, loss: 0.0415
# Epoch 187:
# Training accuracy: 54.35%, loss: 0.0134
# Validaion accuracy: 16.07%, loss: 0.0386
# Epoch 188:
# Training accuracy: 59.48%, loss: 0.0139
# Validaion accuracy: 20.83%, loss: 0.0433
# Epoch 189:
# Training accuracy: 59.88%, loss: 0.0123
# Validaion accuracy: 21.71%, loss: 0.0377
# Epoch 190:
# Training accuracy: 59.32%, loss: 0.0104
# Validaion accuracy: 14.76%, loss: 0.0358
# Epoch 191:
# Training accuracy: 60.87%, loss: 0.0108
# Validaion accuracy: 19.74%, loss: 0.0427
# Epoch 192:
# Training accuracy: 51.26%, loss: 0.0234
# Validaion accuracy: 13.66%, loss: 0.0441
# Epoch 193:
# Training accuracy: 53.50%, loss: 0.0153
# Validaion accuracy: 23.00%, loss: 0.0424
# Epoch 194:
# Training accuracy: 59.56%, loss: 0.0162
# Validaion accuracy: 17.45%, loss: 0.0362
# Epoch 195:
# Training accuracy: 60.01%, loss: 0.0142
# Validaion accuracy: 14.03%, loss: 0.0404
# Epoch 196:
# Training accuracy: 62.09%, loss: 0.0106
# Validaion accuracy: 23.50%, loss: 0.0354
# Epoch 197:
# Training accuracy: 61.12%, loss: 0.0114
# Validaion accuracy: 17.21%, loss: 0.0371
# Epoch 198:
# Training accuracy: 57.35%, loss: 0.0127
# Validaion accuracy: 20.26%, loss: 0.0338
# Epoch 199:
# Training accuracy: 56.68%, loss: 0.0107
# Validaion accuracy: 20.88%, loss: 0.0364
# Epoch 200:
# Training accuracy: 59.14%, loss: 0.0109
# Validaion accuracy: 19.71%, loss: 0.0356

# %%
test_dataloader = Dataloader(test_dataset)
model.load_model(MODEL_PATH)
model.test(test_dataloader)
# Out:
# Got 1544 correct prediction in 10000 test data, accuracy: 15.44%
